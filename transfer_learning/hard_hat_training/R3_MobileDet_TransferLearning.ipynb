# %%
import datetime
start_time = datetime.datetime.now().strftime("%d %b, %H:%M:%S")
start_time
# Out:
# '30 Jan, 02:55:13'

# %%
#take a look at the kind of GPU we have
# !nvidia-smi
# Out:
# Sun Jan 31 04:28:30 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Number of training steps - 1000 will train very quickly, but more steps will increase accuracy.
num_steps = 100000  # 200000 to improve

# Number of evaluation steps.
num_eval_steps = 50

MODELS_CONFIG = {
    'mobilenet_tpu': {
        'model_name': 'ssdlite_mobilenet_edgetpu_coco_quant',
        'pipeline_file': 'ssdlite_mobilenet_edgetpu_320x320_coco_quant.config',
        'batch_size': 32
    },
    'mobilenet': {
        'model_name': 'ssd_mobilenet_v2_coco_2018_03_29',
        'pipeline_file': 'ssd_mobilenet_v2_coco.config',
        'batch_size': 32
    },
    'mobiledet_tpu': {
        'model_name': 'ssdlite_mobiledet_edgetpu_320x320_coco_2020_05_19',
        'pipeline_file': 'ssdlite_mobiledet_edgetpu_320x320_coco_sync_4x4.config',
        'batch_size': 32
    },
    'mobiledet': {
        'model_name': 'ssdlite_mobiledet_cpu_320x320_coco_2020_05_19',
        'pipeline_file': 'ssdlite_mobiledet_cpu_320x320_coco_sync_4x4.config',
        'batch_size': 32
    },    
}

# Pick the model you want to use
# Select a model in `MODELS_CONFIG`.
selected_model = 'mobiledet'

# Name of the object detection model to use.
MODEL = MODELS_CONFIG[selected_model]['model_name']

# Name of the pipline file in tensorflow object detection API.
pipeline_file = MODELS_CONFIG[selected_model]['pipeline_file']

# Training batch size fits in Colabe's Tesla K80 GPU memory for selected model.
batch_size = MODELS_CONFIG[selected_model]['batch_size']

print("Selected model:", MODEL)
# Out:
# Selected model: ssdlite_mobiledet_cpu_320x320_coco_2020_05_19

# %%
# use TF 1.x for Object Detection APIs as they are not ported to TF 2.0 yet
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# ## Install required packages

# %%
# %cd /content
# !git clone --quiet https://github.com/tensorflow/models.git

# !pip install tf_slim

# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk

# !pip install -q Cython contextlib2 pillow lxml matplotlib

# !pip install -q pycocotools

# !pip install lvis

# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# !python object_detection/builders/model_builder_test.py
# Out:
# /content
# Collecting tf_slim
#   Downloading https://files.pythonhosted.org/packages/02/97/b0f4a64df018ca018cc035d44f2ef08f91e2e8aa67271f6f19633a015ff7/tf_slim-1.1.0-py2.py3-none-any.whl (352kB)
#      |████████████████████████████████| 358kB 4.0MB/s
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from tf_slim) (0.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py>=0.2.2->tf_slim) (1.15.0)
# Installing collected packages: tf-slim
# Successfully installed tf-slim-1.1.0
# Selecting previously unselected package python-bs4.
# (Reading database ... 146374 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../4-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../5-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../6-python-lxml_4.2.1-1ubuntu0.3_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.3) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../7-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../8-python-pil_5.1.0-1ubuntu0.4_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1ubuntu0.4) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-bs4 (4.6.0-1) ...
# Setting up python-lxml:amd64 (4.2.1-1ubuntu0.3) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up python-pil:amd64 (5.1.0-1ubuntu0.4) ...
# Setting up python-webencodings (0.5-2) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up python-html5lib (0.999999999-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting lvis
#   Downloading https://files.pythonhosted.org/packages/72/b6/1992240ab48310b5360bfdd1d53163f43bb97d90dc5dc723c67d41c38e78/lvis-0.5.3-py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.4.0 in /usr/local/lib/python3.6/dist-packages (from lvis) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.6/dist-packages (from lvis) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from lvis) (1.3.1)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.6/dist-packages (from lvis) (1.19.5)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.6/dist-packages (from lvis) (0.10.0)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.6/dist-packages (from lvis) (3.2.2)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.6/dist-packages (from lvis) (4.1.2.30)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from lvis) (1.15.0)
# Requirement already satisfied: Cython>=0.29.12 in /usr/local/lib/python3.6/dist-packages (from lvis) (0.29.21)
# Installing collected packages: lvis
# Successfully installed lvis-0.5.3
# /content/models/research

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd

# %cd /content

drive_id = '1vZ9h2Jtwl_KZbGl7U-jdX9V1cSK2tq1z'  # Hardhat
# drive_id = '1a8CavWcehN_aYGOrSS8VM4iC_VEkyW2P'  # Scratch

gdd.download_file_from_google_drive(file_id=drive_id,
                                    dest_path='./dataset.zip',
                                    unzip=True)

# !rm dataset.zip

# !mv data_tfrecord data
# Out:
# /content
# Downloading 1vZ9h2Jtwl_KZbGl7U-jdX9V1cSK2tq1z into ./dataset.zip... Done.
# Unzipping...Done.

# %%
# !curl -L "https://public.roboflow.com/ds/ub0NLZ3ABo?key=G7EycgLLK6" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %cd /content/

# %%
# NOTE: Update these TFRecord names from "cells" and "cells_label_map" to your files!
test_record_fname = '/content/data/data_test.tfrecord'
valid_record_fname = '/content/data/data_valid.tfrecord'
train_record_fname = '/content/data/data_train.tfrecord'
label_map_pbtxt_fname = '/content/data/label_map.pbtxt'

# %% [markdown]
# ## Download base model

# %%
import os
import shutil
import glob
import urllib.request
import tarfile
MODEL_FILE = MODEL + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'
DEST_DIR = '/content/pretrained_model'

if not (os.path.exists(MODEL_FILE)):
    urllib.request.urlretrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
    shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)

# %%
# !echo {DEST_DIR}
# !ls -alh {DEST_DIR}
# Out:
# /content/pretrained_model
# total 121M
# drwxr-x--- 2 475825 89939 4.0K May 19  2020 .
# drwxr-xr-x 1 root   root  4.0K Jan 30 02:56 ..
# -rw-r----- 1 475825 89939  32M May 19  2020 model.ckpt-400000.data-00000-of-00001
# -rw-r----- 1 475825 89939  14K May 19  2020 model.ckpt-400000.index
# -rw-r----- 1 475825 89939 9.9M May 19  2020 model.ckpt-400000.meta
# -rw-r----- 1 475825 89939  16M May 19  2020 model.tflite
# -rw-r----- 1 475825 89939 4.6K May 19  2020 pipeline.config
# -rw-r----- 1 475825 89939  17M May 19  2020 tflite_graph.pb
# -rw-r----- 1 475825 89939  47M May 19  2020 tflite_graph.pbtxt

# %%
fine_tune_checkpoint = os.path.join(DEST_DIR, "model.ckpt")
fine_tune_checkpoint
# Out:
# '/content/pretrained_model/model.ckpt'

# %% [markdown]
# ## Configuring a Training Pipeline

# %%
# %cd /content/models/research

def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())

num_classes = get_num_classes(label_map_pbtxt_fname)

# %cd /content/
# Out:
# /content/models/research
# /content

# %%
# Edit Pipeline config to load in our new tfrecord that we just created and add quantization aware training.
import tensorflow as tf
from google.protobuf import text_format
from object_detection.protos import pipeline_pb2

pipeline = pipeline_pb2.TrainEvalPipelineConfig()                                                                                                                                                                                                          
config_path = '/content/models/research/object_detection/samples/configs/' + pipeline_file
with tf.gfile.GFile(config_path, "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline)

pipeline.train_input_reader.tf_record_input_reader.input_path[:] = [train_record_fname]
pipeline.train_input_reader.label_map_path = label_map_pbtxt_fname
pipeline.eval_input_reader[0].tf_record_input_reader.input_path[:] = [valid_record_fname]
pipeline.eval_input_reader[0].label_map_path = label_map_pbtxt_fname
pipeline.train_config.fine_tune_checkpoint = fine_tune_checkpoint
pipeline.train_config.batch_size = batch_size  # Smaller batch size on free gpu to avoid OOM Killer
pipeline.train_config.num_steps = num_steps  # Less steps with free gpu but 10k should be good enough
pipeline.model.ssd.num_classes = num_classes
pipeline.eval_config.metrics_set[:] = ['coco_detection_metrics']
pipeline.eval_config.use_moving_averages = False
# pipeline.eval_config.ClearField("max_evals")


# Quantization Aware Training
# pipeline.graph_rewriter.quantization.delay = 0
# pipeline.graph_rewriter.quantization.weight_bits = 8
# pipeline.graph_rewriter.quantization.activation_bits = 8

config_text = text_format.MessageToString(pipeline)                                                                                                                                                                                                        
with tf.gfile.Open(config_path, "wb") as f:                                                                                                                                                                                                                       
    f.write(config_text)

# This is out config after modifying.
# !cat $config_path
# Out:
# model {
#   ssd {
#     num_classes: 3
#     image_resizer {
#       fixed_shape_resizer {
#         height: 320
#         width: 320
#       }
#     }
#     feature_extractor {
#       type: "ssd_mobiledet_cpu"
#       depth_multiplier: 1.0
#       min_depth: 16
#       conv_hyperparams {
#         regularizer {
#           l2_regularizer {
#             weight: 4e-05
#           }
#         }
#         initializer {
#           truncated_normal_initializer {
#             mean: 0.0
#             stddev: 0.03
#           }
#         }
#         activation: RELU_6
#         batch_norm {
#           decay: 0.97
#           center: true
#           scale: true
#           epsilon: 0.001
#           train: true
#         }
#       }
#       use_depthwise: true
#       override_base_feature_extractor_hyperparams: false
#     }
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#         use_matmul_gather: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     box_predictor {
#       convolutional_box_predictor {
#         conv_hyperparams {
#           regularizer {
#             l2_regularizer {
#               weight: 4e-05
#             }
#           }
#           initializer {
#             random_normal_initializer {
#               mean: 0.0
#               stddev: 0.03
#             }
#           }
#           activation: RELU_6
#           batch_norm {
#             decay: 0.97
#             center: true
#             scale: true
#             epsilon: 0.001
#             train: true
#           }
#         }
#         min_depth: 0
#         max_depth: 0
#         num_layers_before_predictor: 0
#         use_dropout: false
#         dropout_keep_probability: 0.8
#         kernel_size: 3
#         box_code_size: 4
#         apply_sigmoid_to_scores: false
#         class_prediction_bias_init: -4.6
#         use_depthwise: true
#       }
#     }
#     anchor_generator {
#       ssd_anchor_generator {
#         num_layers: 6
#         min_scale: 0.2
#         max_scale: 0.95
#         aspect_ratios: 1.0
#         aspect_ratios: 2.0
#         aspect_ratios: 0.5
#         aspect_ratios: 3.0
#         aspect_ratios: 0.3333
#       }
#     }
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 1e-08
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 100
#         use_static_shapes: true
#       }
#       score_converter: SIGMOID
#     }
#     normalize_loss_by_num_matches: true
#     loss {
#       localization_loss {
#         weighted_smooth_l1 {
#           delta: 1.0
#         }
#       }
#       classification_loss {
#         weighted_sigmoid_focal {
#           gamma: 2.0
#           alpha: 0.75
#         }
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     encode_background_as_zeros: true
#     normalize_loc_loss_by_codesize: true
#     inplace_batchnorm_update: true
#     freeze_batchnorm: false
#   }
# }
# train_config {
#   batch_size: 32
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     ssd_random_crop {
#     }
#   }
#   sync_replicas: true
#   optimizer {
#     momentum_optimizer {
#       learning_rate {
#         cosine_decay_learning_rate {
#           learning_rate_base: 0.8
#           total_steps: 400000
#           warmup_learning_rate: 0.13333
#           warmup_steps: 2000
#         }
#       }
#       momentum_optimizer_value: 0.9
#     }
#     use_moving_average: false
#   }
#   fine_tune_checkpoint: "/content/pretrained_model/model.ckpt"
#   num_steps: 100000
#   startup_delay_steps: 0.0
#   replicas_to_aggregate: 32
#   max_number_of_boxes: 100
#   unpad_groundtruth_tensors: false
# }
# train_input_reader {
#   label_map_path: "/content/data/label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "/content/data/data_train.tfrecord"
#   }
# }
# eval_config {
#   num_examples: 8000
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
# }
# eval_input_reader {
#   label_map_path: "/content/data/label_map.pbtxt"
#   shuffle: false
#   num_epochs: 1
#   tf_record_input_reader {
#     input_path: "/content/data/data_valid.tfrecord"
#   }
# }

# %%
model_dir = 'training/'
# Optionally remove content in output model directory to fresh start.
# !rm -rf {model_dir}
os.makedirs(model_dir, exist_ok=True)

# %% [markdown]
# ## Train the model

# %%
print(config_path)
print(num_steps)
# Out:
# /content/models/research/object_detection/samples/configs/ssdlite_mobiledet_cpu_320x320_coco_sync_4x4.config
# 100000

# %%
# !python /content/models/research/object_detection/model_main.py \
    --pipeline_config_path={config_path} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --num_eval_steps={num_eval_steps}
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:global_step/sec: 1.81374
# I0130 12:04:07.197188 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81374
# INFO:tensorflow:loss = 0.5778139, step = 50400 (55.135 sec)
# I0130 12:04:07.198473 139896251348864 basic_session_run_hooks.py:260] loss = 0.5778139, step = 50400 (55.135 sec)
# INFO:tensorflow:global_step/sec: 1.80056
# I0130 12:05:02.735476 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80056
# INFO:tensorflow:loss = 0.6283126, step = 50500 (55.538 sec)
# I0130 12:05:02.736867 139896251348864 basic_session_run_hooks.py:260] loss = 0.6283126, step = 50500 (55.538 sec)
# INFO:tensorflow:global_step/sec: 1.78283
# I0130 12:05:58.826046 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.78283
# INFO:tensorflow:loss = 0.7016244, step = 50600 (56.091 sec)
# I0130 12:05:58.827522 139896251348864 basic_session_run_hooks.py:260] loss = 0.7016244, step = 50600 (56.091 sec)
# INFO:tensorflow:global_step/sec: 1.78565
# I0130 12:06:54.828079 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.78565
# INFO:tensorflow:loss = 0.52951056, step = 50700 (56.002 sec)
# I0130 12:06:54.829233 139896251348864 basic_session_run_hooks.py:260] loss = 0.52951056, step = 50700 (56.002 sec)
# INFO:tensorflow:global_step/sec: 1.79183
# I0130 12:07:50.637036 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.79183
# INFO:tensorflow:loss = 0.5700114, step = 50800 (55.809 sec)
# I0130 12:07:50.638457 139896251348864 basic_session_run_hooks.py:260] loss = 0.5700114, step = 50800 (55.809 sec)
# INFO:tensorflow:Saving checkpoints for 50804 into training/model.ckpt.
# I0130 12:07:52.342665 139896251348864 basic_session_run_hooks.py:606] Saving checkpoints for 50804 into training/model.ckpt.
# INFO:tensorflow:Reading unweighted datasets: ['/content/data/data_valid.tfrecord']
# I0130 12:07:53.855781 139896251348864 dataset_builder.py:163] Reading unweighted datasets: ['/content/data/data_valid.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/content/data/data_valid.tfrecord']
# I0130 12:07:53.856977 139896251348864 dataset_builder.py:80] Reading record datasets for input file: ['/content/data/data_valid.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I0130 12:07:53.857131 139896251348864 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0130 12:07:53.857267 139896251348864 dataset_builder.py:88] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f38c7c47ac8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W0130 12:07:53.904621 139896251348864 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f38c7c47ac8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f3b2864a7b8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0130 12:07:54.160259 139896251348864 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f3b2864a7b8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I0130 12:07:54.880684 139896251348864 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:07:58.192860 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:07:58.272912 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:07:58.355168 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:07:58.435832 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:07:58.523599 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:07:58.602460 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Done calling model_fn.
# I0130 12:08:00.198689 139896251348864 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-30T12:08:00Z
# I0130 12:08:00.218418 139896251348864 evaluation.py:255] Starting evaluation at 2021-01-30T12:08:00Z
# INFO:tensorflow:Graph was finalized.
# I0130 12:08:00.953035 139896251348864 monitored_session.py:240] Graph was finalized.
# 2021-01-30 12:08:00.953801: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:08:00.954323: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-01-30 12:08:00.954426: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-30 12:08:00.954489: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-01-30 12:08:00.954540: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-01-30 12:08:00.954605: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-01-30 12:08:00.954654: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-01-30 12:08:00.954748: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-01-30 12:08:00.954802: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-01-30 12:08:00.954906: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:08:00.955444: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:08:00.955977: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-01-30 12:08:00.956036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-30 12:08:00.956062: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-01-30 12:08:00.956081: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-01-30 12:08:00.956239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:08:00.956759: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:08:00.957238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-50804
# I0130 12:08:00.958379 139896251348864 saver.py:1284] Restoring parameters from training/model.ckpt-50804
# INFO:tensorflow:Running local_init_op.
# I0130 12:08:02.298643 139896251348864 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0130 12:08:02.466597 139896251348864 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 1055 images.
# I0130 12:08:51.027730 139892144903936 coco_evaluation.py:293] Performing evaluation on 1055 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0130 12:08:51.034514 139892144903936 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.09s)
# I0130 12:08:51.125776 139892144903936 coco_tools.py:138] DONE (t=0.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=7.33s).
# Accumulating evaluation results...
# DONE (t=1.09s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.161
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.395
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.094
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.236
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.240
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.091
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.335
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.156
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.373
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.513
# INFO:tensorflow:Finished evaluation at 2021-01-30-12:08:59
# I0130 12:08:59.799796 139896251348864 evaluation.py:275] Finished evaluation at 2021-01-30-12:08:59
# INFO:tensorflow:Saving dict for global step 50804: DetectionBoxes_Precision/mAP = 0.16069283, DetectionBoxes_Precision/mAP (large) = 0.2404992, DetectionBoxes_Precision/mAP (medium) = 0.2360826, DetectionBoxes_Precision/mAP (small) = 0.08067167, DetectionBoxes_Precision/mAP@.50IOU = 0.39477244, DetectionBoxes_Precision/mAP@.75IOU = 0.09359354, DetectionBoxes_Recall/AR@1 = 0.09127475, DetectionBoxes_Recall/AR@10 = 0.30119938, DetectionBoxes_Recall/AR@100 = 0.33485952, DetectionBoxes_Recall/AR@100 (large) = 0.51317114, DetectionBoxes_Recall/AR@100 (medium) = 0.37340602, DetectionBoxes_Recall/AR@100 (small) = 0.15593462, Loss/classification_loss = 0.49963644, Loss/localization_loss = 0.30520794, Loss/regularization_loss = 0.18361025, Loss/total_loss = 0.98845655, global_step = 50804, learning_rate = 0.77068454, loss = 0.98845655
# I0130 12:08:59.800119 139896251348864 estimator.py:2049] Saving dict for global step 50804: DetectionBoxes_Precision/mAP = 0.16069283, DetectionBoxes_Precision/mAP (large) = 0.2404992, DetectionBoxes_Precision/mAP (medium) = 0.2360826, DetectionBoxes_Precision/mAP (small) = 0.08067167, DetectionBoxes_Precision/mAP@.50IOU = 0.39477244, DetectionBoxes_Precision/mAP@.75IOU = 0.09359354, DetectionBoxes_Recall/AR@1 = 0.09127475, DetectionBoxes_Recall/AR@10 = 0.30119938, DetectionBoxes_Recall/AR@100 = 0.33485952, DetectionBoxes_Recall/AR@100 (large) = 0.51317114, DetectionBoxes_Recall/AR@100 (medium) = 0.37340602, DetectionBoxes_Recall/AR@100 (small) = 0.15593462, Loss/classification_loss = 0.49963644, Loss/localization_loss = 0.30520794, Loss/regularization_loss = 0.18361025, Loss/total_loss = 0.98845655, global_step = 50804, learning_rate = 0.77068454, loss = 0.98845655
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50804: training/model.ckpt-50804
# I0130 12:08:59.804037 139896251348864 estimator.py:2109] Saving 'checkpoint_path' summary for global step 50804: training/model.ckpt-50804
# INFO:tensorflow:global_step/sec: 0.809142
# I0130 12:09:54.224604 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 0.809142
# INFO:tensorflow:loss = 0.8151767, step = 50900 (123.587 sec)
# I0130 12:09:54.225825 139896251348864 basic_session_run_hooks.py:260] loss = 0.8151767, step = 50900 (123.587 sec)
# INFO:tensorflow:global_step/sec: 1.80948
# I0130 12:10:49.489005 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80948
# INFO:tensorflow:loss = 0.7798016, step = 51000 (55.264 sec)
# I0130 12:10:49.490005 139896251348864 basic_session_run_hooks.py:260] loss = 0.7798016, step = 51000 (55.264 sec)
# INFO:tensorflow:global_step/sec: 1.80159
# I0130 12:11:44.995607 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80159
# INFO:tensorflow:loss = 0.71327835, step = 51100 (55.507 sec)
# I0130 12:11:44.996590 139896251348864 basic_session_run_hooks.py:260] loss = 0.71327835, step = 51100 (55.507 sec)
# INFO:tensorflow:global_step/sec: 1.81585
# I0130 12:12:40.066198 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81585
# INFO:tensorflow:loss = 0.53938186, step = 51200 (55.071 sec)
# I0130 12:12:40.067668 139896251348864 basic_session_run_hooks.py:260] loss = 0.53938186, step = 51200 (55.071 sec)
# INFO:tensorflow:global_step/sec: 1.80117
# I0130 12:13:35.585680 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80117
# INFO:tensorflow:loss = 1.4819932, step = 51300 (55.519 sec)
# I0130 12:13:35.586938 139896251348864 basic_session_run_hooks.py:260] loss = 1.4819932, step = 51300 (55.519 sec)
# INFO:tensorflow:global_step/sec: 1.79606
# I0130 12:14:31.263023 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.79606
# INFO:tensorflow:loss = 1.320288, step = 51400 (55.677 sec)
# I0130 12:14:31.263960 139896251348864 basic_session_run_hooks.py:260] loss = 1.320288, step = 51400 (55.677 sec)
# INFO:tensorflow:global_step/sec: 1.80529
# I0130 12:15:26.655896 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80529
# INFO:tensorflow:loss = 1.2078053, step = 51500 (55.393 sec)
# I0130 12:15:26.657020 139896251348864 basic_session_run_hooks.py:260] loss = 1.2078053, step = 51500 (55.393 sec)
# INFO:tensorflow:global_step/sec: 1.79727
# I0130 12:16:22.295847 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.79727
# INFO:tensorflow:loss = 1.1467506, step = 51600 (55.640 sec)
# I0130 12:16:22.297357 139896251348864 basic_session_run_hooks.py:260] loss = 1.1467506, step = 51600 (55.640 sec)
# INFO:tensorflow:global_step/sec: 1.79994
# I0130 12:17:17.853346 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.79994
# INFO:tensorflow:loss = 1.1737598, step = 51700 (55.557 sec)
# I0130 12:17:17.854488 139896251348864 basic_session_run_hooks.py:260] loss = 1.1737598, step = 51700 (55.557 sec)
# INFO:tensorflow:Saving checkpoints for 51764 into training/model.ckpt.
# I0130 12:17:52.775073 139896251348864 basic_session_run_hooks.py:606] Saving checkpoints for 51764 into training/model.ckpt.
# INFO:tensorflow:Reading unweighted datasets: ['/content/data/data_valid.tfrecord']
# I0130 12:17:54.389832 139896251348864 dataset_builder.py:163] Reading unweighted datasets: ['/content/data/data_valid.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/content/data/data_valid.tfrecord']
# I0130 12:17:54.390920 139896251348864 dataset_builder.py:80] Reading record datasets for input file: ['/content/data/data_valid.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I0130 12:17:54.391086 139896251348864 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0130 12:17:54.391222 139896251348864 dataset_builder.py:88] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f38c0024400>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W0130 12:17:54.432486 139896251348864 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f38c0024400>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f3bcf7d4378> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0130 12:17:54.629904 139896251348864 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f3bcf7d4378> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I0130 12:17:55.248697 139896251348864 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:17:58.712595 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:17:58.803721 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:17:58.893790 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:17:58.991816 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:17:59.082988 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:17:59.182661 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Done calling model_fn.
# I0130 12:18:00.750604 139896251348864 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-30T12:18:00Z
# I0130 12:18:00.767625 139896251348864 evaluation.py:255] Starting evaluation at 2021-01-30T12:18:00Z
# INFO:tensorflow:Graph was finalized.
# I0130 12:18:01.430770 139896251348864 monitored_session.py:240] Graph was finalized.
# 2021-01-30 12:18:01.431441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:18:01.431993: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-01-30 12:18:01.432094: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-30 12:18:01.432154: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-01-30 12:18:01.432204: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-01-30 12:18:01.432257: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-01-30 12:18:01.432313: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-01-30 12:18:01.432367: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-01-30 12:18:01.432415: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-01-30 12:18:01.432515: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:18:01.433034: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:18:01.433463: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-01-30 12:18:01.433553: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-30 12:18:01.433591: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-01-30 12:18:01.433615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-01-30 12:18:01.433731: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:18:01.434233: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:18:01.434729: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-51764
# I0130 12:18:01.435926 139896251348864 saver.py:1284] Restoring parameters from training/model.ckpt-51764
# INFO:tensorflow:Running local_init_op.
# I0130 12:18:02.652429 139896251348864 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0130 12:18:02.796646 139896251348864 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 1055 images.
# I0130 12:18:47.719067 139892144903936 coco_evaluation.py:293] Performing evaluation on 1055 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0130 12:18:47.724722 139892144903936 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.09s)
# I0130 12:18:47.812771 139892144903936 coco_tools.py:138] DONE (t=0.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=7.08s).
# Accumulating evaluation results...
# DONE (t=1.07s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.128
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.075
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.054
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.360
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.521
# INFO:tensorflow:Finished evaluation at 2021-01-30-12:18:56
# I0130 12:18:56.212895 139896251348864 evaluation.py:275] Finished evaluation at 2021-01-30-12:18:56
# INFO:tensorflow:Saving dict for global step 51764: DetectionBoxes_Precision/mAP = 0.12833542, DetectionBoxes_Precision/mAP (large) = 0.290217, DetectionBoxes_Precision/mAP (medium) = 0.19311005, DetectionBoxes_Precision/mAP (small) = 0.054451138, DetectionBoxes_Precision/mAP@.50IOU = 0.31901622, DetectionBoxes_Precision/mAP@.75IOU = 0.07517051, DetectionBoxes_Recall/AR@1 = 0.096165486, DetectionBoxes_Recall/AR@10 = 0.29317102, DetectionBoxes_Recall/AR@100 = 0.32930124, DetectionBoxes_Recall/AR@100 (large) = 0.5209622, DetectionBoxes_Recall/AR@100 (medium) = 0.35984257, DetectionBoxes_Recall/AR@100 (small) = 0.14491607, Loss/classification_loss = 0.49349052, Loss/localization_loss = 0.32376257, Loss/regularization_loss = 0.366274, Loss/total_loss = 1.1835294, global_step = 51764, learning_rate = 0.7695349, loss = 1.1835294
# I0130 12:18:56.213234 139896251348864 estimator.py:2049] Saving dict for global step 51764: DetectionBoxes_Precision/mAP = 0.12833542, DetectionBoxes_Precision/mAP (large) = 0.290217, DetectionBoxes_Precision/mAP (medium) = 0.19311005, DetectionBoxes_Precision/mAP (small) = 0.054451138, DetectionBoxes_Precision/mAP@.50IOU = 0.31901622, DetectionBoxes_Precision/mAP@.75IOU = 0.07517051, DetectionBoxes_Recall/AR@1 = 0.096165486, DetectionBoxes_Recall/AR@10 = 0.29317102, DetectionBoxes_Recall/AR@100 = 0.32930124, DetectionBoxes_Recall/AR@100 (large) = 0.5209622, DetectionBoxes_Recall/AR@100 (medium) = 0.35984257, DetectionBoxes_Recall/AR@100 (small) = 0.14491607, Loss/classification_loss = 0.49349052, Loss/localization_loss = 0.32376257, Loss/regularization_loss = 0.366274, Loss/total_loss = 1.1835294, global_step = 51764, learning_rate = 0.7695349, loss = 1.1835294
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 51764: training/model.ckpt-51764
# I0130 12:18:56.217496 139896251348864 estimator.py:2109] Saving 'checkpoint_path' summary for global step 51764: training/model.ckpt-51764
# INFO:tensorflow:global_step/sec: 0.841278
# I0130 12:19:16.720189 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 0.841278
# INFO:tensorflow:loss = 0.99549496, step = 51800 (118.867 sec)
# I0130 12:19:16.721334 139896251348864 basic_session_run_hooks.py:260] loss = 0.99549496, step = 51800 (118.867 sec)
# INFO:tensorflow:global_step/sec: 1.80396
# I0130 12:20:12.153869 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80396
# INFO:tensorflow:loss = 0.888209, step = 51900 (55.434 sec)
# I0130 12:20:12.155040 139896251348864 basic_session_run_hooks.py:260] loss = 0.888209, step = 51900 (55.434 sec)
# INFO:tensorflow:global_step/sec: 1.80388
# I0130 12:21:07.589928 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80388
# INFO:tensorflow:loss = 0.93981737, step = 52000 (55.436 sec)
# I0130 12:21:07.591012 139896251348864 basic_session_run_hooks.py:260] loss = 0.93981737, step = 52000 (55.436 sec)
# INFO:tensorflow:global_step/sec: 1.79936
# I0130 12:22:03.165157 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.79936
# INFO:tensorflow:loss = 0.84287596, step = 52100 (55.575 sec)
# I0130 12:22:03.166028 139896251348864 basic_session_run_hooks.py:260] loss = 0.84287596, step = 52100 (55.575 sec)
# INFO:tensorflow:global_step/sec: 1.804
# I0130 12:22:58.597481 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.804
# INFO:tensorflow:loss = 1.0018153, step = 52200 (55.433 sec)
# I0130 12:22:58.598864 139896251348864 basic_session_run_hooks.py:260] loss = 1.0018153, step = 52200 (55.433 sec)
# INFO:tensorflow:global_step/sec: 1.81029
# I0130 12:23:53.837184 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81029
# INFO:tensorflow:loss = 0.87869173, step = 52300 (55.240 sec)
# I0130 12:23:53.838617 139896251348864 basic_session_run_hooks.py:260] loss = 0.87869173, step = 52300 (55.240 sec)
# INFO:tensorflow:global_step/sec: 1.80233
# I0130 12:24:49.321105 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80233
# INFO:tensorflow:loss = 0.7498758, step = 52400 (55.484 sec)
# I0130 12:24:49.322136 139896251348864 basic_session_run_hooks.py:260] loss = 0.7498758, step = 52400 (55.484 sec)
# INFO:tensorflow:global_step/sec: 1.81432
# I0130 12:25:44.438119 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81432
# INFO:tensorflow:loss = 0.80514944, step = 52500 (55.117 sec)
# I0130 12:25:44.439078 139896251348864 basic_session_run_hooks.py:260] loss = 0.80514944, step = 52500 (55.117 sec)
# INFO:tensorflow:global_step/sec: 1.80133
# I0130 12:26:39.952586 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80133
# INFO:tensorflow:loss = 0.85745907, step = 52600 (55.515 sec)
# I0130 12:26:39.953787 139896251348864 basic_session_run_hooks.py:260] loss = 0.85745907, step = 52600 (55.515 sec)
# INFO:tensorflow:global_step/sec: 1.80803
# I0130 12:27:35.261420 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80803
# INFO:tensorflow:loss = 0.85614306, step = 52700 (55.309 sec)
# I0130 12:27:35.262701 139896251348864 basic_session_run_hooks.py:260] loss = 0.85614306, step = 52700 (55.309 sec)
# INFO:tensorflow:Saving checkpoints for 52733 into training/model.ckpt.
# I0130 12:27:53.015777 139896251348864 basic_session_run_hooks.py:606] Saving checkpoints for 52733 into training/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (600 secs).
# I0130 12:27:54.344784 139896251348864 training.py:527] Skip the current checkpoint eval due to throttle secs (600 secs).
# INFO:tensorflow:global_step/sec: 1.76619
# I0130 12:28:31.880261 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.76619
# INFO:tensorflow:loss = 0.77906275, step = 52800 (56.619 sec)
# I0130 12:28:31.881333 139896251348864 basic_session_run_hooks.py:260] loss = 0.77906275, step = 52800 (56.619 sec)
# INFO:tensorflow:global_step/sec: 1.81119
# I0130 12:29:27.092791 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81119
# INFO:tensorflow:loss = 0.8108763, step = 52900 (55.213 sec)
# I0130 12:29:27.094027 139896251348864 basic_session_run_hooks.py:260] loss = 0.8108763, step = 52900 (55.213 sec)
# INFO:tensorflow:global_step/sec: 1.81068
# I0130 12:30:22.320595 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81068
# INFO:tensorflow:loss = 0.94908625, step = 53000 (55.228 sec)
# I0130 12:30:22.321658 139896251348864 basic_session_run_hooks.py:260] loss = 0.94908625, step = 53000 (55.228 sec)
# INFO:tensorflow:global_step/sec: 1.79951
# I0130 12:31:17.891296 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.79951
# INFO:tensorflow:loss = 0.78060824, step = 53100 (55.571 sec)
# I0130 12:31:17.892377 139896251348864 basic_session_run_hooks.py:260] loss = 0.78060824, step = 53100 (55.571 sec)
# INFO:tensorflow:global_step/sec: 1.7949
# I0130 12:32:13.604735 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.7949
# INFO:tensorflow:loss = 0.82009125, step = 53200 (55.713 sec)
# I0130 12:32:13.605708 139896251348864 basic_session_run_hooks.py:260] loss = 0.82009125, step = 53200 (55.713 sec)
# INFO:tensorflow:global_step/sec: 1.7945
# I0130 12:33:09.330629 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.7945
# INFO:tensorflow:loss = 0.7138778, step = 53300 (55.726 sec)
# I0130 12:33:09.331815 139896251348864 basic_session_run_hooks.py:260] loss = 0.7138778, step = 53300 (55.726 sec)
# INFO:tensorflow:global_step/sec: 1.81321
# I0130 12:34:04.481548 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81321
# INFO:tensorflow:loss = 0.714212, step = 53400 (55.151 sec)
# I0130 12:34:04.482736 139896251348864 basic_session_run_hooks.py:260] loss = 0.714212, step = 53400 (55.151 sec)
# INFO:tensorflow:global_step/sec: 1.80293
# I0130 12:34:59.946866 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80293
# INFO:tensorflow:loss = 0.70079744, step = 53500 (55.465 sec)
# I0130 12:34:59.947864 139896251348864 basic_session_run_hooks.py:260] loss = 0.70079744, step = 53500 (55.465 sec)
# INFO:tensorflow:global_step/sec: 1.79611
# I0130 12:35:55.622599 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.79611
# INFO:tensorflow:loss = 0.81024194, step = 53600 (55.676 sec)
# I0130 12:35:55.624083 139896251348864 basic_session_run_hooks.py:260] loss = 0.81024194, step = 53600 (55.676 sec)
# INFO:tensorflow:global_step/sec: 1.79302
# I0130 12:36:51.394371 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.79302
# INFO:tensorflow:loss = 0.77741075, step = 53700 (55.771 sec)
# I0130 12:36:51.395446 139896251348864 basic_session_run_hooks.py:260] loss = 0.77741075, step = 53700 (55.771 sec)
# INFO:tensorflow:global_step/sec: 1.8063
# I0130 12:37:46.756244 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.8063
# INFO:tensorflow:loss = 0.58921283, step = 53800 (55.362 sec)
# I0130 12:37:46.757622 139896251348864 basic_session_run_hooks.py:260] loss = 0.58921283, step = 53800 (55.362 sec)
# INFO:tensorflow:Saving checkpoints for 53813 into training/model.ckpt.
# I0130 12:37:53.459447 139896251348864 basic_session_run_hooks.py:606] Saving checkpoints for 53813 into training/model.ckpt.
# INFO:tensorflow:Reading unweighted datasets: ['/content/data/data_valid.tfrecord']
# I0130 12:37:54.897558 139896251348864 dataset_builder.py:163] Reading unweighted datasets: ['/content/data/data_valid.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/content/data/data_valid.tfrecord']
# I0130 12:37:54.898671 139896251348864 dataset_builder.py:80] Reading record datasets for input file: ['/content/data/data_valid.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I0130 12:37:54.898804 139896251348864 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0130 12:37:54.898921 139896251348864 dataset_builder.py:88] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f38c1992240>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W0130 12:37:54.938354 139896251348864 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f38c1992240>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f38c1300840> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0130 12:37:55.134341 139896251348864 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f38c1300840> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I0130 12:37:55.795451 139896251348864 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:37:59.395207 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:37:59.476623 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:37:59.561597 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:37:59.644099 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:37:59.740752 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 12:37:59.822278 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Done calling model_fn.
# I0130 12:38:01.317659 139896251348864 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-30T12:38:01Z
# I0130 12:38:01.335048 139896251348864 evaluation.py:255] Starting evaluation at 2021-01-30T12:38:01Z
# INFO:tensorflow:Graph was finalized.
# I0130 12:38:02.029980 139896251348864 monitored_session.py:240] Graph was finalized.
# 2021-01-30 12:38:02.030660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:38:02.031237: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-01-30 12:38:02.031345: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-30 12:38:02.031410: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-01-30 12:38:02.031454: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-01-30 12:38:02.031501: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-01-30 12:38:02.031550: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-01-30 12:38:02.031605: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-01-30 12:38:02.031646: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-01-30 12:38:02.031785: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:38:02.032321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:38:02.032752: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-01-30 12:38:02.032841: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-30 12:38:02.032869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-01-30 12:38:02.032883: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-01-30 12:38:02.032983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:38:02.033452: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 12:38:02.033882: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-53813
# I0130 12:38:02.035006 139896251348864 saver.py:1284] Restoring parameters from training/model.ckpt-53813
# INFO:tensorflow:Running local_init_op.
# I0130 12:38:03.329448 139896251348864 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0130 12:38:03.511506 139896251348864 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 1055 images.
# I0130 12:38:50.943132 139892144903936 coco_evaluation.py:293] Performing evaluation on 1055 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0130 12:38:50.948385 139892144903936 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.10s)
# I0130 12:38:51.044462 139892144903936 coco_tools.py:138] DONE (t=0.10s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=6.88s).
# Accumulating evaluation results...
# DONE (t=1.10s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.221
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.117
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.307
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.386
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.418
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.564
# INFO:tensorflow:Finished evaluation at 2021-01-30-12:38:59
# I0130 12:38:59.280454 139896251348864 evaluation.py:275] Finished evaluation at 2021-01-30-12:38:59
# INFO:tensorflow:Saving dict for global step 53813: DetectionBoxes_Precision/mAP = 0.22085467, DetectionBoxes_Precision/mAP (large) = 0.38622448, DetectionBoxes_Precision/mAP (medium) = 0.30745035, DetectionBoxes_Precision/mAP (small) = 0.116926685, DetectionBoxes_Precision/mAP@.50IOU = 0.4488477, DetectionBoxes_Precision/mAP@.75IOU = 0.19252849, DetectionBoxes_Recall/AR@1 = 0.124021746, DetectionBoxes_Recall/AR@10 = 0.35020202, DetectionBoxes_Recall/AR@100 = 0.378895, DetectionBoxes_Recall/AR@100 (large) = 0.5638376, DetectionBoxes_Recall/AR@100 (medium) = 0.41765237, DetectionBoxes_Recall/AR@100 (small) = 0.20594025, Loss/classification_loss = 0.41370097, Loss/localization_loss = 0.2485544, Loss/regularization_loss = 0.21400349, Loss/total_loss = 0.8762569, global_step = 53813, learning_rate = 0.7670103, loss = 0.8762569
# I0130 12:38:59.280906 139896251348864 estimator.py:2049] Saving dict for global step 53813: DetectionBoxes_Precision/mAP = 0.22085467, DetectionBoxes_Precision/mAP (large) = 0.38622448, DetectionBoxes_Precision/mAP (medium) = 0.30745035, DetectionBoxes_Precision/mAP (small) = 0.116926685, DetectionBoxes_Precision/mAP@.50IOU = 0.4488477, DetectionBoxes_Precision/mAP@.75IOU = 0.19252849, DetectionBoxes_Recall/AR@1 = 0.124021746, DetectionBoxes_Recall/AR@10 = 0.35020202, DetectionBoxes_Recall/AR@100 = 0.378895, DetectionBoxes_Recall/AR@100 (large) = 0.5638376, DetectionBoxes_Recall/AR@100 (medium) = 0.41765237, DetectionBoxes_Recall/AR@100 (small) = 0.20594025, Loss/classification_loss = 0.41370097, Loss/localization_loss = 0.2485544, Loss/regularization_loss = 0.21400349, Loss/total_loss = 0.8762569, global_step = 53813, learning_rate = 0.7670103, loss = 0.8762569
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 53813: training/model.ckpt-53813
# I0130 12:38:59.284482 139896251348864 estimator.py:2109] Saving 'checkpoint_path' summary for global step 53813: training/model.ckpt-53813
# INFO:tensorflow:global_step/sec: 0.821763
# I0130 12:39:48.445758 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 0.821763
# INFO:tensorflow:loss = 0.6193864, step = 53900 (121.689 sec)
# I0130 12:39:48.446792 139896251348864 basic_session_run_hooks.py:260] loss = 0.6193864, step = 53900 (121.689 sec)
# INFO:tensorflow:global_step/sec: 1.79434
# I0130 12:40:44.176611 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.79434
# INFO:tensorflow:loss = 0.62373817, step = 54000 (55.731 sec)
# I0130 12:40:44.177696 139896251348864 basic_session_run_hooks.py:260] loss = 0.62373817, step = 54000 (55.731 sec)
# INFO:tensorflow:global_step/sec: 1.78575
# I0130 12:41:40.175623 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.78575
# INFO:tensorflow:loss = 0.6783582, step = 54100 (55.999 sec)
# I0130 12:41:40.176736 139896251348864 basic_session_run_hooks.py:260] loss = 0.6783582, step = 54100 (55.999 sec)
# INFO:tensorflow:global_step/sec: 1.78425
# I0130 12:42:36.221509 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.78425
# INFO:tensorflow:loss = 0.6127639, step = 54200 (56.046 sec)
# I0130 12:42:36.222660 139896251348864 basic_session_run_hooks.py:260] loss = 0.6127639, step = 54200 (56.046 sec)
# INFO:tensorflow:global_step/sec: 1.79359
# I0130 12:43:31.975499 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.79359
# INFO:tensorflow:loss = 0.7931539, step = 54300 (55.754 sec)
# I0130 12:43:31.976752 139896251348864 basic_session_run_hooks.py:260] loss = 0.7931539, step = 54300 (55.754 sec)
# INFO:tensorflow:global_step/sec: 1.80063
# I0130 12:44:27.511747 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80063
# INFO:tensorflow:loss = 0.70504344, step = 54400 (55.536 sec)
# I0130 12:44:27.512989 139896251348864 basic_session_run_hooks.py:260] loss = 0.70504344, step = 54400 (55.536 sec)
# INFO:tensorflow:global_step/sec: 1.79305
# I0130 12:45:23.282736 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.79305
# INFO:tensorflow:loss = 0.7003244, step = 54500 (55.771 sec)
# I0130 12:45:23.283876 139896251348864 basic_session_run_hooks.py:260] loss = 0.7003244, step = 54500 (55.771 sec)
# INFO:tensorflow:global_step/sec: 1.7764
# I0130 12:46:19.576354 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.7764
# ...
# I0130 18:49:11.994486 139896251348864 estimator.py:2049] Saving dict for global step 89908: DetectionBoxes_Precision/mAP = 0.16152434, DetectionBoxes_Precision/mAP (large) = 0.3299264, DetectionBoxes_Precision/mAP (medium) = 0.25798646, DetectionBoxes_Precision/mAP (small) = 0.095677525, DetectionBoxes_Precision/mAP@.50IOU = 0.3838536, DetectionBoxes_Precision/mAP@.75IOU = 0.1062007, DetectionBoxes_Recall/AR@1 = 0.106588535, DetectionBoxes_Recall/AR@10 = 0.31419644, DetectionBoxes_Recall/AR@100 = 0.34830356, DetectionBoxes_Recall/AR@100 (large) = 0.5081871, DetectionBoxes_Recall/AR@100 (medium) = 0.386196, DetectionBoxes_Recall/AR@100 (small) = 0.19494237, Loss/classification_loss = 0.46890622, Loss/localization_loss = 0.2757018, Loss/regularization_loss = 0.17767212, Loss/total_loss = 0.92227817, global_step = 89908, learning_rate = 0.70750374, loss = 0.92227817
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 89908: training/model.ckpt-89908
# I0130 18:49:11.998127 139896251348864 estimator.py:2109] Saving 'checkpoint_path' summary for global step 89908: training/model.ckpt-89908
# INFO:tensorflow:global_step/sec: 0.809891
# I0130 18:50:03.290315 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 0.809891
# INFO:tensorflow:loss = 0.52604175, step = 90000 (123.474 sec)
# I0130 18:50:03.291587 139896251348864 basic_session_run_hooks.py:260] loss = 0.52604175, step = 90000 (123.474 sec)
# INFO:tensorflow:global_step/sec: 1.81137
# I0130 18:50:58.497083 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81137
# INFO:tensorflow:loss = 0.56298643, step = 90100 (55.207 sec)
# I0130 18:50:58.498212 139896251348864 basic_session_run_hooks.py:260] loss = 0.56298643, step = 90100 (55.207 sec)
# INFO:tensorflow:global_step/sec: 1.81373
# I0130 18:51:53.631965 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81373
# INFO:tensorflow:loss = 0.608486, step = 90200 (55.135 sec)
# I0130 18:51:53.633322 139896251348864 basic_session_run_hooks.py:260] loss = 0.608486, step = 90200 (55.135 sec)
# INFO:tensorflow:global_step/sec: 1.82139
# I0130 18:52:48.535050 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.82139
# INFO:tensorflow:loss = 0.54931456, step = 90300 (54.903 sec)
# I0130 18:52:48.536306 139896251348864 basic_session_run_hooks.py:260] loss = 0.54931456, step = 90300 (54.903 sec)
# INFO:tensorflow:global_step/sec: 1.81156
# I0130 18:53:43.736163 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81156
# INFO:tensorflow:loss = 0.6047399, step = 90400 (55.201 sec)
# I0130 18:53:43.737297 139896251348864 basic_session_run_hooks.py:260] loss = 0.6047399, step = 90400 (55.201 sec)
# INFO:tensorflow:global_step/sec: 1.80745
# I0130 18:54:39.062638 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80745
# INFO:tensorflow:loss = 0.5117458, step = 90500 (55.327 sec)
# I0130 18:54:39.063807 139896251348864 basic_session_run_hooks.py:260] loss = 0.5117458, step = 90500 (55.327 sec)
# INFO:tensorflow:global_step/sec: 1.80717
# I0130 18:55:34.397682 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.80717
# INFO:tensorflow:loss = 0.53344166, step = 90600 (55.335 sec)
# I0130 18:55:34.399010 139896251348864 basic_session_run_hooks.py:260] loss = 0.53344166, step = 90600 (55.335 sec)
# INFO:tensorflow:global_step/sec: 1.81831
# I0130 18:56:29.393899 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81831
# INFO:tensorflow:loss = 0.81918025, step = 90700 (54.996 sec)
# I0130 18:56:29.394986 139896251348864 basic_session_run_hooks.py:260] loss = 0.81918025, step = 90700 (54.996 sec)
# INFO:tensorflow:global_step/sec: 1.8125
# I0130 18:57:24.566218 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.8125
# INFO:tensorflow:loss = 0.57290465, step = 90800 (55.172 sec)
# I0130 18:57:24.567437 139896251348864 basic_session_run_hooks.py:260] loss = 0.57290465, step = 90800 (55.172 sec)
# INFO:tensorflow:Saving checkpoints for 90872 into training/model.ckpt.
# I0130 18:58:03.722755 139896251348864 basic_session_run_hooks.py:606] Saving checkpoints for 90872 into training/model.ckpt.
# INFO:tensorflow:Reading unweighted datasets: ['/content/data/data_valid.tfrecord']
# I0130 18:58:05.096184 139896251348864 dataset_builder.py:163] Reading unweighted datasets: ['/content/data/data_valid.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/content/data/data_valid.tfrecord']
# I0130 18:58:05.097137 139896251348864 dataset_builder.py:80] Reading record datasets for input file: ['/content/data/data_valid.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I0130 18:58:05.097397 139896251348864 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0130 18:58:05.097539 139896251348864 dataset_builder.py:88] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f38c1bf2a90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W0130 18:58:05.135421 139896251348864 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f38c1bf2a90>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f3b9bfb59d8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0130 18:58:05.326747 139896251348864 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f3b9bfb59d8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I0130 18:58:05.942191 139896251348864 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 18:58:09.208216 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 18:58:09.306065 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 18:58:09.398534 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 18:58:09.499432 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 18:58:09.597969 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0130 18:58:09.697557 139896251348864 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Done calling model_fn.
# I0130 18:58:11.198947 139896251348864 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-30T18:58:11Z
# I0130 18:58:11.215764 139896251348864 evaluation.py:255] Starting evaluation at 2021-01-30T18:58:11Z
# INFO:tensorflow:Graph was finalized.
# I0130 18:58:12.170927 139896251348864 monitored_session.py:240] Graph was finalized.
# 2021-01-30 18:58:12.171664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 18:58:12.172177: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-01-30 18:58:12.172287: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-30 18:58:12.172332: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-01-30 18:58:12.172383: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-01-30 18:58:12.172427: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-01-30 18:58:12.172469: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-01-30 18:58:12.172515: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-01-30 18:58:12.172560: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-01-30 18:58:12.172674: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 18:58:12.173157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 18:58:12.173601: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-01-30 18:58:12.173696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-30 18:58:12.173719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-01-30 18:58:12.173732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-01-30 18:58:12.173852: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 18:58:12.174328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-30 18:58:12.174776: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-90872
# I0130 18:58:12.175826 139896251348864 saver.py:1284] Restoring parameters from training/model.ckpt-90872
# INFO:tensorflow:Running local_init_op.
# I0130 18:58:13.376591 139896251348864 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0130 18:58:13.522710 139896251348864 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 1055 images.
# I0130 18:58:59.573919 139892144903936 coco_evaluation.py:293] Performing evaluation on 1055 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0130 18:58:59.578245 139892144903936 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.09s)
# I0130 18:58:59.664452 139892144903936 coco_tools.py:138] DONE (t=0.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=6.54s).
# Accumulating evaluation results...
# DONE (t=0.96s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.226
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.199
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.122
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.309
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.370
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.397
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.548
# INFO:tensorflow:Finished evaluation at 2021-01-30-18:59:07
# I0130 18:59:07.414519 139896251348864 evaluation.py:275] Finished evaluation at 2021-01-30-18:59:07
# INFO:tensorflow:Saving dict for global step 90872: DetectionBoxes_Precision/mAP = 0.22625208, DetectionBoxes_Precision/mAP (large) = 0.31587768, DetectionBoxes_Precision/mAP (medium) = 0.30905372, DetectionBoxes_Precision/mAP (small) = 0.122400634, DetectionBoxes_Precision/mAP@.50IOU = 0.4655136, DetectionBoxes_Precision/mAP@.75IOU = 0.1990883, DetectionBoxes_Recall/AR@1 = 0.12256265, DetectionBoxes_Recall/AR@10 = 0.36990535, DetectionBoxes_Recall/AR@100 = 0.39692166, DetectionBoxes_Recall/AR@100 (large) = 0.5477502, DetectionBoxes_Recall/AR@100 (medium) = 0.43234304, DetectionBoxes_Recall/AR@100 (small) = 0.19549046, Loss/classification_loss = 0.3346621, Loss/localization_loss = 0.23309045, Loss/regularization_loss = 0.16757616, Loss/total_loss = 0.73532814, global_step = 90872, learning_rate = 0.7055483, loss = 0.73532814
# I0130 18:59:07.414852 139896251348864 estimator.py:2049] Saving dict for global step 90872: DetectionBoxes_Precision/mAP = 0.22625208, DetectionBoxes_Precision/mAP (large) = 0.31587768, DetectionBoxes_Precision/mAP (medium) = 0.30905372, DetectionBoxes_Precision/mAP (small) = 0.122400634, DetectionBoxes_Precision/mAP@.50IOU = 0.4655136, DetectionBoxes_Precision/mAP@.75IOU = 0.1990883, DetectionBoxes_Recall/AR@1 = 0.12256265, DetectionBoxes_Recall/AR@10 = 0.36990535, DetectionBoxes_Recall/AR@100 = 0.39692166, DetectionBoxes_Recall/AR@100 (large) = 0.5477502, DetectionBoxes_Recall/AR@100 (medium) = 0.43234304, DetectionBoxes_Recall/AR@100 (small) = 0.19549046, Loss/classification_loss = 0.3346621, Loss/localization_loss = 0.23309045, Loss/regularization_loss = 0.16757616, Loss/total_loss = 0.73532814, global_step = 90872, learning_rate = 0.7055483, loss = 0.73532814
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 90872: training/model.ckpt-90872
# I0130 18:59:07.418442 139896251348864 estimator.py:2109] Saving 'checkpoint_path' summary for global step 90872: training/model.ckpt-90872
# INFO:tensorflow:global_step/sec: 0.841375
# I0130 18:59:23.419228 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 0.841375
# INFO:tensorflow:loss = 0.5601716, step = 90900 (118.853 sec)
# I0130 18:59:23.420496 139896251348864 basic_session_run_hooks.py:260] loss = 0.5601716, step = 90900 (118.853 sec)
# INFO:tensorflow:global_step/sec: 1.81781
# I0130 19:00:18.430392 139896251348864 basic_session_run_hooks.py:692] global_step/sec: 1.81781
# INFO:tensorflow:loss = 0.5994594, step = 91000 (55.011 sec)
# I0130 19:00:18.431499 139896251348864 basic_session_run_hooks.py:260] loss = 0.5994594, step = 91000 (55.011 sec)

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir {model_dir}

# %%
end_time = datetime.datetime.now().strftime("%d %b, %H:%M:%S")
print(start_time)
print(end_time)

# %% [markdown]
# ## Exporting a Trained Inference Graph
# Once your training job is complete, you need to extract the newly trained inference graph, which will be later used to perform the object detection. This can be done as follows:

# %%
import re
import numpy as np

output_directory = './fine_tuned_model'

lst = os.listdir(model_dir)
lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
last_model = lst[steps.argmax()].replace('.meta', '')

last_model_path = os.path.join(model_dir, last_model)
print(last_model_path)
# !python /content/models/research/object_detection/export_inference_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path={config_path} \
    --output_directory={output_directory} \
    --trained_checkpoint_prefix={last_model_path}

# %%
import os

pb_fname = os.path.join(os.path.abspath(output_directory), "frozen_inference_graph.pb")
assert os.path.isfile(pb_fname), '`{}` not exist'.format(pb_fname)

# %% [markdown]
# ## Test accuracy on test images

# %%
pipeline = pipeline_pb2.TrainEvalPipelineConfig()                                                                                                                                                                                                          
config_path = '/content/models/research/object_detection/samples/configs/' + pipeline_file
with tf.gfile.GFile(config_path, "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline)

pipeline.eval_input_reader[0].tf_record_input_reader.input_path[:] = [test_record_fname]
pipeline.train_config.batch_size = 1

config_text = text_format.MessageToString(pipeline)                                                                                                                                                                                                        
with tf.gfile.Open(config_path, "wb") as f:                                                                                                                                                                                                                       
    f.write(config_text)

# This is out config after modifying.
# !cat $config_path

# %%
# !python /content/models/research/object_detection/model_main.py \
    --pipeline_config_path={config_path} \
    --checkpoint_dir=/content/fine_tuned_model/ \
    --alsologtostderr \
    --run_once=True

# %% [markdown]
# ## Run inference test
# Test with images in repository `tensorflow-object-detection/test` directory.
#
# **To test with your own images, you need to place your images inside the `test` directory in this Colab notebook!** More on this below.

# %%
# %cd /content/
drive_id = '1ibLkMEG5NWHmulieEa7vJOPq5c4emg7L'  # Hardhat
# drive_id = '15XRe167DzTYb7S6fNDAVCrnIr05GJ6jf'  # Scratch

gdd.download_file_from_google_drive(file_id=drive_id,
                                    dest_path='./dataset.zip',
                                    unzip=True)
# !rm dataset.zip

# %%
import os
import glob

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = pb_fname

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = label_map_pbtxt_fname

# If you want to test the code with your images, just add images files to the PATH_TO_TEST_IMAGES_DIR.
PATH_TO_TEST_IMAGES_DIR =  '/content/hardhat_test_images/'

assert os.path.isfile(pb_fname)
assert os.path.isfile(PATH_TO_LABELS)
TEST_IMAGE_PATHS = glob.glob(os.path.join(PATH_TO_TEST_IMAGES_DIR, "*.jpg*"))
assert len(TEST_IMAGE_PATHS) > 0, 'No image found in `{}`.'.format(PATH_TO_TEST_IMAGES_DIR)
TEST_IMAGE_PATHS = sorted(TEST_IMAGE_PATHS)
print(TEST_IMAGE_PATHS)

# %%
# %cd /content/models/research/object_detection

import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops


# This is needed to display the images.
# %matplotlib inline


from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')


label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(
    label_map, max_num_classes=num_classes, use_display_name=True)
category_index = label_map_util.create_category_index(categories)


def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
        (im_height, im_width, 3)).astype(np.uint8)

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)


def run_inference_for_single_image(image, graph):
    with graph.as_default():
        with tf.Session() as sess:
            # Get handles to input and output tensors
            ops = tf.get_default_graph().get_operations()
            all_tensor_names = {
                output.name for op in ops for output in op.outputs}
            tensor_dict = {}
            for key in [
                'num_detections', 'detection_boxes', 'detection_scores',
                'detection_classes', 'detection_masks'
            ]:
                tensor_name = key + ':0'
                if tensor_name in all_tensor_names:
                    tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
                        tensor_name)
            if 'detection_masks' in tensor_dict:
                # The following processing is only for single image
                detection_boxes = tf.squeeze(
                    tensor_dict['detection_boxes'], [0])
                detection_masks = tf.squeeze(
                    tensor_dict['detection_masks'], [0])
                # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
                real_num_detection = tf.cast(
                    tensor_dict['num_detections'][0], tf.int32)
                detection_boxes = tf.slice(detection_boxes, [0, 0], [
                                           real_num_detection, -1])
                detection_masks = tf.slice(detection_masks, [0, 0, 0], [
                                           real_num_detection, -1, -1])
                detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                    detection_masks, detection_boxes, image.shape[0], image.shape[1])
                detection_masks_reframed = tf.cast(
                    tf.greater(detection_masks_reframed, 0.5), tf.uint8)
                # Follow the convention by adding back the batch dimension
                tensor_dict['detection_masks'] = tf.expand_dims(
                    detection_masks_reframed, 0)
            image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

            # Run inference
            output_dict = sess.run(tensor_dict,
                                   feed_dict={image_tensor: np.expand_dims(image, 0)})

            # all outputs are float32 numpy arrays, so convert types as appropriate
            output_dict['num_detections'] = int(
                output_dict['num_detections'][0])
            output_dict['detection_classes'] = output_dict[
                'detection_classes'][0].astype(np.uint8)
            output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
            output_dict['detection_scores'] = output_dict['detection_scores'][0]
            if 'detection_masks' in output_dict:
                output_dict['detection_masks'] = output_dict['detection_masks'][0]
    return output_dict

# %%
# Output images not showing? Run this cell again, and try the cell above
# This is needed to display the images.
# %matplotlib inline

# %%
len(TEST_IMAGE_PATHS)

# %%
from tqdm import tqdm

for image_path in tqdm(TEST_IMAGE_PATHS[:100]):
    image = Image.open(image_path)
    # the array based representation of the image will be used later in order to prepare the
    # result image with boxes and labels on it.
    image_np = load_image_into_numpy_array(image)
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    # Actual detection.
    output_dict = run_inference_for_single_image(image_np, detection_graph)
    # Visualization of the results of a detection.
    vis_util.visualize_boxes_and_labels_on_image_array(
        image_np,
        output_dict['detection_boxes'],
        output_dict['detection_classes'],
        output_dict['detection_scores'],
        category_index,
        instance_masks=output_dict.get('detection_masks'),
        use_normalized_coordinates=True,
        line_thickness=4)
    plt.figure(figsize=IMAGE_SIZE)
    plt.imshow(image_np)
    save_name = '.'.join(image_path.split('.')[:-1]) + '_prediction.jpg'
    plt.savefig(save_name, bbox_inches='tight')

# %%
from google.colab import files

# !zip -r /content/mobiledet.zip /content/fine_tuned_model/
# files.download("/content/mobiledet.zip")

# %%
#take a look at the kind of GPU we have
# !nvidia-smi

# %%
# Download inferred images

# !mkdir /content/result_images
# !cp /content/hardhat_test_images/*_prediction.jpg /content/result_images/

# !zip -r /content/mobiledet_img_results.zip /content/result_images
# files.download("/content/mobiledet_img_results.zip")
