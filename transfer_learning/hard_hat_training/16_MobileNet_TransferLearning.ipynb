# %%
import datetime
start_time = datetime.datetime.now().strftime("%d %b, %H:%M:%S")
start_time

dataset = 2  # 1: hardhat, 2: scratch

# %%
# Number of training steps - 1000 will train very quickly, but more steps will increase accuracy.
num_steps = 100000  # 200000 to improve

# Number of evaluation steps.
num_eval_steps = 50

MODELS_CONFIG = {
    'mobilenet_tpu': {
        'model_name': 'ssdlite_mobilenet_edgetpu_coco_quant',
        'pipeline_file': 'ssdlite_mobilenet_edgetpu_320x320_coco_quant.config',
        'batch_size': 32
    },
    'mobilenet': {
        'model_name': 'ssd_mobilenet_v2_coco_2018_03_29',
        'pipeline_file': 'ssd_mobilenet_v2_coco.config',
        'batch_size': 32
    },
    'mobilenet_ssdlite': {
        'model_name': 'ssdlite_mobilenet_v2_coco_2018_05_09',
        'pipeline_file': 'ssd_mobilenet_v2_coco.config',
        'batch_size': 32
    },
    'mobiledet_tpu': {
        'model_name': 'ssdlite_mobiledet_edgetpu_320x320_coco_2020_05_19',
        'pipeline_file': 'ssdlite_mobiledet_edgetpu_320x320_coco_sync_4x4.config',
        'batch_size': 32
    },
    'mobiledet': {
        'model_name': 'ssdlite_mobiledet_cpu_320x320_coco_2020_05_19',
        'pipeline_file': 'ssdlite_mobiledet_cpu_320x320_coco_sync_4x4.config',
        'batch_size': 32
    },    
}

# Pick the model you want to use
# Select a model in `MODELS_CONFIG`.
selected_model = 'mobilenet'

# Name of the object detection model to use.
MODEL = MODELS_CONFIG[selected_model]['model_name']

# Name of the pipline file in tensorflow object detection API.
pipeline_file = MODELS_CONFIG[selected_model]['pipeline_file']

# Training batch size fits in Colabe's Tesla K80 GPU memory for selected model.
batch_size = MODELS_CONFIG[selected_model]['batch_size']

print("Selected model:", MODEL)
# Out:
# Selected model: ssd_mobilenet_v2_coco_2018_03_29

# %%
# use TF 1.x for Object Detection APIs as they are not ported to TF 2.0 yet
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# ## Install required packages

# %%
# %cd /content
# !git clone --quiet https://github.com/tensorflow/models.git

# !pip install tf_slim

# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk

# !pip install -q Cython contextlib2 pillow lxml matplotlib

# !pip install -q pycocotools

# !pip install lvis

# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# !python object_detection/builders/model_builder_test.py

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd

# %cd /content

if dataset == 1:
  drive_id = '1HQfrA9eHaIrqohTtNpSu8vCSLaZNpZbn'  # Hardhat
else:
  drive_id = '1a8CavWcehN_aYGOrSS8VM4iC_VEkyW2P'  # Scratch

gdd.download_file_from_google_drive(file_id=drive_id,
                                    dest_path='./dataset.zip',
                                    unzip=True)

# !rm dataset.zip

# !mv data_tfrecord data
# Out:
# /content
# Downloading 1a8CavWcehN_aYGOrSS8VM4iC_VEkyW2P into ./dataset.zip... Done.
# Unzipping...Done.

# %%
# !mkdir /content/data/
# %cd /content/data/
# !curl -L "https://public.roboflow.com/ds/ub0NLZ3ABo?key=G7EycgLLK6" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %cd /content/

# %%
# NOTE: Update these TFRecord names from "cells" and "cells_label_map" to your files!
test_record_fname = '/content/data/data_test.tfrecord'
valid_record_fname = '/content/data/data_valid.tfrecord'
train_record_fname = '/content/data/data_train.tfrecord'
label_map_pbtxt_fname = '/content/data/label_map.pbtxt'

# %% [markdown]
# ## Download base model

# %%
import os
import shutil
import glob
import urllib.request
import tarfile


MODEL_FILE = MODEL + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'
DEST_DIR = '/content/pretrained_model'

if not (os.path.exists(MODEL_FILE)):
    urllib.request.urlretrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
    shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)

# %%
# !echo {DEST_DIR}
# !ls -alh {DEST_DIR}
# Out:
# /content/pretrained_model
# total 135M
# drwxr-xr-x 3 345018 89939 4.0K Mar 30  2018 .
# drwxr-xr-x 1 root   root  4.0K Jan 18 22:29 ..
# -rw-r--r-- 1 345018 89939   77 Mar 30  2018 checkpoint
# -rw-r--r-- 1 345018 89939  67M Mar 30  2018 frozen_inference_graph.pb
# -rw-r--r-- 1 345018 89939  65M Mar 30  2018 model.ckpt.data-00000-of-00001
# -rw-r--r-- 1 345018 89939  15K Mar 30  2018 model.ckpt.index
# -rw-r--r-- 1 345018 89939 3.4M Mar 30  2018 model.ckpt.meta
# -rw-r--r-- 1 345018 89939 4.2K Mar 30  2018 pipeline.config
# drwxr-xr-x 3 345018 89939 4.0K Mar 30  2018 saved_model

# %%
fine_tune_checkpoint = os.path.join(DEST_DIR, "model.ckpt")
fine_tune_checkpoint
# Out:
# '/content/pretrained_model/model.ckpt'

# %% [markdown]
# ## Configuring a Training Pipeline

# %%
# %cd /content/models/research

def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())

num_classes = get_num_classes(label_map_pbtxt_fname)

# %cd /content/
# Out:
# /content/models/research
# /content

# %%
# Edit Pipeline config to load in our new tfrecord that we just created and add quantization aware training.
import tensorflow as tf
from google.protobuf import text_format
from object_detection.protos import pipeline_pb2

pipeline = pipeline_pb2.TrainEvalPipelineConfig()                                                                                                                                                                                                          
config_path = '/content/models/research/object_detection/samples/configs/' + pipeline_file
with tf.gfile.GFile(config_path, "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline)

pipeline.train_input_reader.tf_record_input_reader.input_path[:] = [train_record_fname]
pipeline.train_input_reader.label_map_path = label_map_pbtxt_fname
pipeline.eval_input_reader[0].tf_record_input_reader.input_path[:] = [valid_record_fname]
pipeline.eval_input_reader[0].label_map_path = label_map_pbtxt_fname
pipeline.train_config.fine_tune_checkpoint = fine_tune_checkpoint
pipeline.train_config.batch_size = batch_size  # Smaller batch size on free gpu to avoid OOM Killer
pipeline.train_config.num_steps = num_steps  # Less steps with free gpu but 10k should be good enough
pipeline.model.ssd.num_classes = num_classes
pipeline.eval_config.metrics_set[:] = ['coco_detection_metrics']
pipeline.eval_config.use_moving_averages = False
# pipeline.eval_config.ClearField("max_evals")


# Quantization Aware Training
# pipeline.graph_rewriter.quantization.delay = 0
# pipeline.graph_rewriter.quantization.weight_bits = 8
# pipeline.graph_rewriter.quantization.activation_bits = 8

config_text = text_format.MessageToString(pipeline)                                                                                                                                                                                                        
with tf.gfile.Open(config_path, "wb") as f:                                                                                                                                                                                                                       
    f.write(config_text)

# This is out config after modifying.
# !cat $config_path
# Out:
# model {
#   ssd {
#     num_classes: 6
#     image_resizer {
#       fixed_shape_resizer {
#         height: 300
#         width: 300
#       }
#     }
#     feature_extractor {
#       type: "ssd_mobilenet_v2"
#       depth_multiplier: 1.0
#       min_depth: 16
#       conv_hyperparams {
#         regularizer {
#           l2_regularizer {
#             weight: 4e-05
#           }
#         }
#         initializer {
#           truncated_normal_initializer {
#             mean: 0.0
#             stddev: 0.03
#           }
#         }
#         activation: RELU_6
#         batch_norm {
#           decay: 0.9997
#           center: true
#           scale: true
#           epsilon: 0.001
#           train: true
#         }
#       }
#     }
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     box_predictor {
#       convolutional_box_predictor {
#         conv_hyperparams {
#           regularizer {
#             l2_regularizer {
#               weight: 4e-05
#             }
#           }
#           initializer {
#             truncated_normal_initializer {
#               mean: 0.0
#               stddev: 0.03
#             }
#           }
#           activation: RELU_6
#           batch_norm {
#             decay: 0.9997
#             center: true
#             scale: true
#             epsilon: 0.001
#             train: true
#           }
#         }
#         min_depth: 0
#         max_depth: 0
#         num_layers_before_predictor: 0
#         use_dropout: false
#         dropout_keep_probability: 0.8
#         kernel_size: 1
#         box_code_size: 4
#         apply_sigmoid_to_scores: false
#       }
#     }
#     anchor_generator {
#       ssd_anchor_generator {
#         num_layers: 6
#         min_scale: 0.2
#         max_scale: 0.95
#         aspect_ratios: 1.0
#         aspect_ratios: 2.0
#         aspect_ratios: 0.5
#         aspect_ratios: 3.0
#         aspect_ratios: 0.3333
#       }
#     }
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 1e-08
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 100
#       }
#       score_converter: SIGMOID
#     }
#     normalize_loss_by_num_matches: true
#     loss {
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       classification_loss {
#         weighted_sigmoid {
#         }
#       }
#       hard_example_miner {
#         num_hard_examples: 3000
#         iou_threshold: 0.99
#         loss_type: CLASSIFICATION
#         max_negatives_per_positive: 3
#         min_negatives_per_image: 3
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#   }
# }
# train_config {
#   batch_size: 32
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     ssd_random_crop {
#     }
#   }
#   optimizer {
#     rms_prop_optimizer {
#       learning_rate {
#         exponential_decay_learning_rate {
#           initial_learning_rate: 0.004
#           decay_steps: 800720
#           decay_factor: 0.95
#         }
#       }
#       momentum_optimizer_value: 0.9
#       decay: 0.9
#       epsilon: 1.0
#     }
#   }
#   fine_tune_checkpoint: "/content/pretrained_model/model.ckpt"
#   num_steps: 100000
#   fine_tune_checkpoint_type: "detection"
# }
# train_input_reader {
#   label_map_path: "/content/data/label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "/content/data/data_train.tfrecord"
#   }
# }
# eval_config {
#   num_examples: 8000
#   max_evals: 10
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
# }
# eval_input_reader {
#   label_map_path: "/content/data/label_map.pbtxt"
#   shuffle: false
#   num_readers: 1
#   tf_record_input_reader {
#     input_path: "/content/data/data_valid.tfrecord"
#   }
# }

# %%
model_dir = 'training/'
# Optionally remove content in output model directory to fresh start.
# !rm -rf {model_dir}
os.makedirs(model_dir, exist_ok=True)

# %% [markdown]
# ## Train the model

# %%
print(config_path)
print(num_steps)
# Out:
# /content/models/research/object_detection/samples/configs/ssd_mobilenet_v2_coco.config
# 100000

# %%
# !python /content/models/research/object_detection/model_main.py \
    --pipeline_config_path={config_path} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --num_eval_steps={num_eval_steps}
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:28:14.683202 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:28:14.712040 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:28:14.739074 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:28:14.765487 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:28:14.791618 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:28:14.817665 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Done calling model_fn.
# I0118 14:28:16.106618 139877099501440 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-18T14:28:16Z
# I0118 14:28:16.121323 139877099501440 evaluation.py:255] Starting evaluation at 2021-01-18T14:28:16Z
# INFO:tensorflow:Graph was finalized.
# I0118 14:28:16.493290 139877099501440 monitored_session.py:240] Graph was finalized.
# 2021-01-18 14:28:16.493907: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 14:28:16.494376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-01-18 14:28:16.494481: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-18 14:28:16.494510: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-01-18 14:28:16.494536: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-01-18 14:28:16.494557: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-01-18 14:28:16.494584: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-01-18 14:28:16.494605: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-01-18 14:28:16.494628: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-01-18 14:28:16.494726: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 14:28:16.495147: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 14:28:16.495506: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-01-18 14:28:16.495551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-18 14:28:16.495565: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-01-18 14:28:16.495574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-01-18 14:28:16.495678: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 14:28:16.496107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 14:28:16.496493: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-58271
# I0118 14:28:16.498062 139877099501440 saver.py:1284] Restoring parameters from training/model.ckpt-58271
# INFO:tensorflow:Running local_init_op.
# I0118 14:28:17.341582 139877099501440 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0118 14:28:17.456128 139877099501440 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 1055 images.
# I0118 14:28:54.522922 139874612565760 coco_evaluation.py:293] Performing evaluation on 1055 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0118 14:28:54.528222 139874612565760 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.08s)
# I0118 14:28:54.603997 139874612565760 coco_tools.py:138] DONE (t=0.08s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=4.93s).
# Accumulating evaluation results...
# DONE (t=1.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.284
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.549
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.261
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.182
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.376
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.445
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.145
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.438
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.479
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.252
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.494
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.659
# INFO:tensorflow:Finished evaluation at 2021-01-18-14:29:00
# I0118 14:29:00.765142 139877099501440 evaluation.py:275] Finished evaluation at 2021-01-18-14:29:00
# INFO:tensorflow:Saving dict for global step 58271: DetectionBoxes_Precision/mAP = 0.28384778, DetectionBoxes_Precision/mAP (large) = 0.4452899, DetectionBoxes_Precision/mAP (medium) = 0.37645805, DetectionBoxes_Precision/mAP (small) = 0.18227227, DetectionBoxes_Precision/mAP@.50IOU = 0.5487855, DetectionBoxes_Precision/mAP@.75IOU = 0.2612403, DetectionBoxes_Recall/AR@1 = 0.14530681, DetectionBoxes_Recall/AR@10 = 0.43766242, DetectionBoxes_Recall/AR@100 = 0.47904775, DetectionBoxes_Recall/AR@100 (large) = 0.65884054, DetectionBoxes_Recall/AR@100 (medium) = 0.49365327, DetectionBoxes_Recall/AR@100 (small) = 0.25204244, Loss/classification_loss = 3.2355416, Loss/localization_loss = 0.6367563, Loss/regularization_loss = 0.29461908, Loss/total_loss = 4.166923, global_step = 58271, learning_rate = 0.004, loss = 4.166923
# I0118 14:29:00.765444 139877099501440 estimator.py:2049] Saving dict for global step 58271: DetectionBoxes_Precision/mAP = 0.28384778, DetectionBoxes_Precision/mAP (large) = 0.4452899, DetectionBoxes_Precision/mAP (medium) = 0.37645805, DetectionBoxes_Precision/mAP (small) = 0.18227227, DetectionBoxes_Precision/mAP@.50IOU = 0.5487855, DetectionBoxes_Precision/mAP@.75IOU = 0.2612403, DetectionBoxes_Recall/AR@1 = 0.14530681, DetectionBoxes_Recall/AR@10 = 0.43766242, DetectionBoxes_Recall/AR@100 = 0.47904775, DetectionBoxes_Recall/AR@100 (large) = 0.65884054, DetectionBoxes_Recall/AR@100 (medium) = 0.49365327, DetectionBoxes_Recall/AR@100 (small) = 0.25204244, Loss/classification_loss = 3.2355416, Loss/localization_loss = 0.6367563, Loss/regularization_loss = 0.29461908, Loss/total_loss = 4.166923, global_step = 58271, learning_rate = 0.004, loss = 4.166923
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 58271: training/model.ckpt-58271
# I0118 14:29:00.768403 139877099501440 estimator.py:2109] Saving 'checkpoint_path' summary for global step 58271: training/model.ckpt-58271
# INFO:tensorflow:global_step/sec: 1.02229
# I0118 14:29:15.008991 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 1.02229
# INFO:tensorflow:loss = 3.3574982, step = 58300 (97.820 sec)
# I0118 14:29:15.010920 139877099501440 basic_session_run_hooks.py:260] loss = 3.3574982, step = 58300 (97.820 sec)
# INFO:tensorflow:global_step/sec: 2.10435
# I0118 14:30:02.529602 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.10435
# INFO:tensorflow:loss = 3.1553109, step = 58400 (47.520 sec)
# I0118 14:30:02.530583 139877099501440 basic_session_run_hooks.py:260] loss = 3.1553109, step = 58400 (47.520 sec)
# INFO:tensorflow:global_step/sec: 2.08191
# I0118 14:30:50.562323 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.08191
# INFO:tensorflow:loss = 3.393536, step = 58500 (48.033 sec)
# I0118 14:30:50.563369 139877099501440 basic_session_run_hooks.py:260] loss = 3.393536, step = 58500 (48.033 sec)
# INFO:tensorflow:global_step/sec: 2.11059
# I0118 14:31:37.942412 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.11059
# INFO:tensorflow:loss = 3.3939114, step = 58600 (47.380 sec)
# I0118 14:31:37.943551 139877099501440 basic_session_run_hooks.py:260] loss = 3.3939114, step = 58600 (47.380 sec)
# INFO:tensorflow:global_step/sec: 2.06953
# I0118 14:32:26.262572 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.06953
# INFO:tensorflow:loss = 3.0622327, step = 58700 (48.320 sec)
# I0118 14:32:26.263671 139877099501440 basic_session_run_hooks.py:260] loss = 3.0622327, step = 58700 (48.320 sec)
# INFO:tensorflow:global_step/sec: 2.0983
# I0118 14:33:13.920286 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.0983
# INFO:tensorflow:loss = 3.177717, step = 58800 (47.658 sec)
# I0118 14:33:13.921353 139877099501440 basic_session_run_hooks.py:260] loss = 3.177717, step = 58800 (47.658 sec)
# INFO:tensorflow:global_step/sec: 2.09871
# I0118 14:34:01.568461 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.09871
# INFO:tensorflow:loss = 3.995267, step = 58900 (47.648 sec)
# I0118 14:34:01.569720 139877099501440 basic_session_run_hooks.py:260] loss = 3.995267, step = 58900 (47.648 sec)
# INFO:tensorflow:global_step/sec: 2.09179
# I0118 14:34:49.374362 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.09179
# INFO:tensorflow:loss = 2.7921312, step = 59000 (47.806 sec)
# I0118 14:34:49.375446 139877099501440 basic_session_run_hooks.py:260] loss = 2.7921312, step = 59000 (47.806 sec)
# INFO:tensorflow:global_step/sec: 2.1053
# I0118 14:35:36.873446 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.1053
# INFO:tensorflow:loss = 3.5493631, step = 59100 (47.499 sec)
# I0118 14:35:36.874312 139877099501440 basic_session_run_hooks.py:260] loss = 3.5493631, step = 59100 (47.499 sec)
# INFO:tensorflow:global_step/sec: 2.10599
# I0118 14:36:24.357022 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.10599
# INFO:tensorflow:loss = 2.8649912, step = 59200 (47.484 sec)
# I0118 14:36:24.358171 139877099501440 basic_session_run_hooks.py:260] loss = 2.8649912, step = 59200 (47.484 sec)
# INFO:tensorflow:global_step/sec: 2.12169
# I0118 14:37:11.489390 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.12169
# INFO:tensorflow:loss = 3.576407, step = 59300 (47.132 sec)
# I0118 14:37:11.490338 139877099501440 basic_session_run_hooks.py:260] loss = 3.576407, step = 59300 (47.132 sec)
# INFO:tensorflow:global_step/sec: 2.11482
# I0118 14:37:58.774655 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.11482
# INFO:tensorflow:loss = 3.120123, step = 59400 (47.285 sec)
# I0118 14:37:58.775688 139877099501440 basic_session_run_hooks.py:260] loss = 3.120123, step = 59400 (47.285 sec)
# INFO:tensorflow:Saving checkpoints for 59426 into training/model.ckpt.
# I0118 14:38:10.646912 139877099501440 basic_session_run_hooks.py:606] Saving checkpoints for 59426 into training/model.ckpt.
# INFO:tensorflow:Reading unweighted datasets: ['/content/data/data_valid.tfrecord']
# I0118 14:38:12.169408 139877099501440 dataset_builder.py:148] Reading unweighted datasets: ['/content/data/data_valid.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/content/data/data_valid.tfrecord']
# I0118 14:38:12.170341 139877099501440 dataset_builder.py:77] Reading record datasets for input file: ['/content/data/data_valid.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I0118 14:38:12.170484 139877099501440 dataset_builder.py:78] Number of filenames to read: 1
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f3459fa1940>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# W0118 14:38:12.208146 139877099501440 ag_logging.py:146] Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f3459fa1940>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f36b4236ea0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# W0118 14:38:12.369711 139877099501440 ag_logging.py:146] Entity <function eval_input.<locals>.transform_and_pad_input_data_fn at 0x7f36b4236ea0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Calling model_fn.
# I0118 14:38:12.869792 139877099501440 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:38:14.809851 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:38:14.837114 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:38:14.864111 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:38:14.892333 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:38:14.919321 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 14:38:14.950930 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Done calling model_fn.
# I0118 14:38:16.550238 139877099501440 estimator.py:1150] Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-18T14:38:16Z
# I0118 14:38:16.565052 139877099501440 evaluation.py:255] Starting evaluation at 2021-01-18T14:38:16Z
# INFO:tensorflow:Graph was finalized.
# I0118 14:38:16.939429 139877099501440 monitored_session.py:240] Graph was finalized.
# 2021-01-18 14:38:16.940166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 14:38:16.940652: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-01-18 14:38:16.940768: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-18 14:38:16.940799: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-01-18 14:38:16.940829: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-01-18 14:38:16.940855: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-01-18 14:38:16.940886: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-01-18 14:38:16.940912: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-01-18 14:38:16.940940: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-01-18 14:38:16.941081: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 14:38:16.941548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 14:38:16.941894: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-01-18 14:38:16.941977: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-18 14:38:16.941991: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-01-18 14:38:16.942005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-01-18 14:38:16.942145: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 14:38:16.942595: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 14:38:16.942952: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-59426
# I0118 14:38:16.943989 139877099501440 saver.py:1284] Restoring parameters from training/model.ckpt-59426
# INFO:tensorflow:Running local_init_op.
# I0118 14:38:17.822064 139877099501440 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0118 14:38:17.946913 139877099501440 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 1055 images.
# I0118 14:38:54.616516 139874612565760 coco_evaluation.py:293] Performing evaluation on 1055 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0118 14:38:54.622175 139874612565760 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.08s)
# I0118 14:38:54.697887 139874612565760 coco_tools.py:138] DONE (t=0.08s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=5.64s).
# Accumulating evaluation results...
# DONE (t=1.05s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.547
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.381
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.448
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.457
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.501
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.677
# INFO:tensorflow:Finished evaluation at 2021-01-18-14:39:01
# I0118 14:39:01.594367 139877099501440 evaluation.py:275] Finished evaluation at 2021-01-18-14:39:01
# INFO:tensorflow:Saving dict for global step 59426: DetectionBoxes_Precision/mAP = 0.29086483, DetectionBoxes_Precision/mAP (large) = 0.4477282, DetectionBoxes_Precision/mAP (medium) = 0.38109377, DetectionBoxes_Precision/mAP (small) = 0.19273838, DetectionBoxes_Precision/mAP@.50IOU = 0.5468061, DetectionBoxes_Precision/mAP@.75IOU = 0.2849609, DetectionBoxes_Recall/AR@1 = 0.15012461, DetectionBoxes_Recall/AR@10 = 0.45744362, DetectionBoxes_Recall/AR@100 = 0.50116384, DetectionBoxes_Recall/AR@100 (large) = 0.6770883, DetectionBoxes_Recall/AR@100 (medium) = 0.527041, DetectionBoxes_Recall/AR@100 (small) = 0.2682021, Loss/classification_loss = 2.6334462, Loss/localization_loss = 0.63629806, Loss/regularization_loss = 0.29443356, Loss/total_loss = 3.5641763, global_step = 59426, learning_rate = 0.004, loss = 3.5641763
# I0118 14:39:01.594628 139877099501440 estimator.py:2049] Saving dict for global step 59426: DetectionBoxes_Precision/mAP = 0.29086483, DetectionBoxes_Precision/mAP (large) = 0.4477282, DetectionBoxes_Precision/mAP (medium) = 0.38109377, DetectionBoxes_Precision/mAP (small) = 0.19273838, DetectionBoxes_Precision/mAP@.50IOU = 0.5468061, DetectionBoxes_Precision/mAP@.75IOU = 0.2849609, DetectionBoxes_Recall/AR@1 = 0.15012461, DetectionBoxes_Recall/AR@10 = 0.45744362, DetectionBoxes_Recall/AR@100 = 0.50116384, DetectionBoxes_Recall/AR@100 (large) = 0.6770883, DetectionBoxes_Recall/AR@100 (medium) = 0.527041, DetectionBoxes_Recall/AR@100 (small) = 0.2682021, Loss/classification_loss = 2.6334462, Loss/localization_loss = 0.63629806, Loss/regularization_loss = 0.29443356, Loss/total_loss = 3.5641763, global_step = 59426, learning_rate = 0.004, loss = 3.5641763
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.644
# INFO:tensorflow:Finished evaluation at 2021-01-18-14:49:01
# I0118 14:49:01.912358 139877099501440 evaluation.py:275] Finished evaluation at 2021-01-18-14:49:01
# INFO:tensorflow:Saving dict for global step 60587: DetectionBoxes_Precision/mAP = 0.27232304, DetectionBoxes_Precision/mAP (large) = 0.443206, DetectionBoxes_Precision/mAP (medium) = 0.35456344, DetectionBoxes_Precision/mAP (small) = 0.18516393, DetectionBoxes_Precision/mAP@.50IOU = 0.5463127, DetectionBoxes_Precision/mAP@.75IOU = 0.24315166, DetectionBoxes_Recall/AR@1 = 0.13356508, DetectionBoxes_Recall/AR@10 = 0.41976148, DetectionBoxes_Recall/AR@100 = 0.47538763, DetectionBoxes_Recall/AR@100 (large) = 0.6443127, DetectionBoxes_Recall/AR@100 (medium) = 0.48393953, DetectionBoxes_Recall/AR@100 (small) = 0.26412445, Loss/classification_loss = 2.8178904, Loss/localization_loss = 0.7188299, Loss/regularization_loss = 0.2942536, Loss/total_loss = 3.8309767, global_step = 60587, learning_rate = 0.004, loss = 3.8309767
# I0118 14:49:01.912634 139877099501440 estimator.py:2049] Saving dict for global step 60587: DetectionBoxes_Precision/mAP = 0.27232304, DetectionBoxes_Precision/mAP (large) = 0.443206, DetectionBoxes_Precision/mAP (medium) = 0.35456344, DetectionBoxes_Precision/mAP (small) = 0.18516393, DetectionBoxes_Precision/mAP@.50IOU = 0.5463127, DetectionBoxes_Precision/mAP@.75IOU = 0.24315166, DetectionBoxes_Recall/AR@1 = 0.13356508, DetectionBoxes_Recall/AR@10 = 0.41976148, DetectionBoxes_Recall/AR@100 = 0.47538763, DetectionBoxes_Recall/AR@100 (large) = 0.6443127, DetectionBoxes_Recall/AR@100 (medium) = 0.48393953, DetectionBoxes_Recall/AR@100 (small) = 0.26412445, Loss/classification_loss = 2.8178904, Loss/localization_loss = 0.7188299, Loss/regularization_loss = 0.2942536, Loss/total_loss = 3.8309767, global_step = 60587, learning_rate = 0.004, loss = 3.8309767
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 60587: training/model.ckpt-60587
# I0118 14:49:01.915520 139877099501440 estimator.py:2109] Saving 'checkpoint_path' summary for global step 60587: training/model.ckpt-60587
# INFO:tensorflow:global_step/sec: 1.01968
# I0118 14:49:08.567739 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 1.01968
# INFO:tensorflow:loss = 3.6162777, step = 60600 (98.070 sec)
# I0118 14:49:08.568663 139877099501440 basic_session_run_hooks.py:260] loss = 3.6162777, step = 60600 (98.070 sec)
# INFO:tensorflow:global_step/sec: 2.107
# I0118 14:49:56.028545 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.107
# INFO:tensorflow:loss = 3.1147761, step = 60700 (47.461 sec)
# I0118 14:49:56.029980 139877099501440 basic_session_run_hooks.py:260] loss = 3.1147761, step = 60700 (47.461 sec)
# INFO:tensorflow:global_step/sec: 2.11184
# I0118 14:50:43.380573 139877099501440 basic_session_run_hooks.py:692] global_step/sec: 2.11184
# INFO:tensorflow:loss = 3.1326053, step = 60800 (47.352 sec)
).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.550
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.198
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.386
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.417
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.488
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.625
# INFO:tensorflow:Finished evaluation at 2021-01-18-20:27:04
# I0118 20:27:04.273442 139877099501440 evaluation.py:275] Finished evaluation at 2021-01-18-20:27:04
# INFO:tensorflow:Saving dict for global step 100000: DetectionBoxes_Precision/mAP = 0.29233044, DetectionBoxes_Precision/mAP (large) = 0.4248953, DetectionBoxes_Precision/mAP (medium) = 0.38645554, DetectionBoxes_Precision/mAP (small) = 0.1979924, DetectionBoxes_Precision/mAP@.50IOU = 0.54978406, DetectionBoxes_Precision/mAP@.75IOU = 0.2804961, DetectionBoxes_Recall/AR@1 = 0.13250925, DetectionBoxes_Recall/AR@10 = 0.41664827, DetectionBoxes_Recall/AR@100 = 0.4647862, DetectionBoxes_Recall/AR@100 (large) = 0.6248529, DetectionBoxes_Recall/AR@100 (medium) = 0.48816556, DetectionBoxes_Recall/AR@100 (small) = 0.28648192, Loss/classification_loss = 2.805296, Loss/localization_loss = 0.6023808, Loss/regularization_loss = 0.2896527, Loss/total_loss = 3.6973314, global_step = 100000, learning_rate = 0.004, loss = 3.6973314
# I0118 20:27:04.273695 139877099501440 estimator.py:2049] Saving dict for global step 100000: DetectionBoxes_Precision/mAP = 0.29233044, DetectionBoxes_Precision/mAP (large) = 0.4248953, DetectionBoxes_Precision/mAP (medium) = 0.38645554, DetectionBoxes_Precision/mAP (small) = 0.1979924, DetectionBoxes_Precision/mAP@.50IOU = 0.54978406, DetectionBoxes_Precision/mAP@.75IOU = 0.2804961, DetectionBoxes_Recall/AR@1 = 0.13250925, DetectionBoxes_Recall/AR@10 = 0.41664827, DetectionBoxes_Recall/AR@100 = 0.4647862, DetectionBoxes_Recall/AR@100 (large) = 0.6248529, DetectionBoxes_Recall/AR@100 (medium) = 0.48816556, DetectionBoxes_Recall/AR@100 (small) = 0.28648192, Loss/classification_loss = 2.805296, Loss/localization_loss = 0.6023808, Loss/regularization_loss = 0.2896527, Loss/total_loss = 3.6973314, global_step = 100000, learning_rate = 0.004, loss = 3.6973314
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100000: training/model.ckpt-100000
# I0118 20:27:04.276500 139877099501440 estimator.py:2109] Saving 'checkpoint_path' summary for global step 100000: training/model.ckpt-100000
# INFO:tensorflow:Performing the final export in the end of training.
# I0118 20:27:04.277157 139877099501440 exporter.py:410] Performing the final export in the end of training.
# INFO:tensorflow:Calling model_fn.
# I0118 20:27:04.511862 139877099501440 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:06.354576 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:06.381221 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:06.668770 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:06.695005 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:06.720968 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:06.747193 139877099501440 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Done calling model_fn.
# I0118 20:27:07.377042 139877099501440 estimator.py:1150] Done calling model_fn.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0118 20:27:07.377305 139877099501440 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# I0118 20:27:07.377874 139877099501440 export_utils.py:170] Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# I0118 20:27:07.377987 139877099501440 export_utils.py:170] Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# I0118 20:27:07.378065 139877099501440 export_utils.py:170] Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# I0118 20:27:07.378139 139877099501440 export_utils.py:170] Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# I0118 20:27:07.378203 139877099501440 export_utils.py:170] Signatures INCLUDED in export for Eval: None
# 2021-01-18 20:27:07.378683: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:07.379100: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-01-18 20:27:07.379221: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-18 20:27:07.379255: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-01-18 20:27:07.379280: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-01-18 20:27:07.379303: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-01-18 20:27:07.379330: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-01-18 20:27:07.379352: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-01-18 20:27:07.379373: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-01-18 20:27:07.379463: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:07.379886: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:07.380248: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-01-18 20:27:07.380293: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-18 20:27:07.380308: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-01-18 20:27:07.380318: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-01-18 20:27:07.380424: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:07.380819: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:07.381177: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-100000
# I0118 20:27:07.383481 139877099501440 saver.py:1284] Restoring parameters from training/model.ckpt-100000
# INFO:tensorflow:Assets added to graph.
# I0118 20:27:07.796808 139877099501440 builder_impl.py:665] Assets added to graph.
# INFO:tensorflow:No assets to write.
# I0118 20:27:07.797018 139877099501440 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: training/export/Servo/temp-b'1611001624'/saved_model.pb
# I0118 20:27:08.444152 139877099501440 builder_impl.py:425] SavedModel written to: training/export/Servo/temp-b'1611001624'/saved_model.pb
# INFO:tensorflow:Loss for final step: 2.4535813.
# I0118 20:27:08.840074 139877099501440 estimator.py:371] Loss for final step: 2.4535813.

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir {model_dir}

# %%
end_time = datetime.datetime.now().strftime("%d %b, %H:%M:%S")
print(start_time)
print(end_time)
# Out:
# 18 Jan, 06:05:55
# 18 Jan, 20:27:15

# %% [markdown]
# ## Exporting a Trained Inference Graph
# Once your training job is complete, you need to extract the newly trained inference graph, which will be later used to perform the object detection. This can be done as follows:

# %%
import re
import numpy as np

output_directory = './fine_tuned_model'

lst = os.listdir(model_dir)
lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
last_model = lst[steps.argmax()].replace('.meta', '')

last_model_path = os.path.join(model_dir, last_model)
print(last_model_path)
# !python /content/models/research/object_detection/export_inference_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path={config_path} \
    --output_directory={output_directory} \
    --trained_checkpoint_prefix={last_model_path}
# Out:
# training/model.ckpt-100000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0118 20:27:18.325351 140375671650176 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:20.224323 140375671650176 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:20.258222 140375671650176 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:20.291309 140375671650176 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:20.324015 140375671650176 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:20.356884 140375671650176 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0118 20:27:20.389443 140375671650176 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /content/models/research/object_detection/core/post_processing.py:595: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0118 20:27:20.709894 140375671650176 deprecation.py:323] From /content/models/research/object_detection/core/post_processing.py:595: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:474: get_or_create_global_step (from tf_slim.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# W0118 20:27:21.062735 140375671650176 deprecation.py:323] From /content/models/research/object_detection/exporter.py:474: get_or_create_global_step (from tf_slim.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:653: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# W0118 20:27:21.065752 140375671650176 deprecation.py:323] From /content/models/research/object_detection/exporter.py:653: print_model_analysis (from tensorflow.contrib.tfprof.model_analyzer) is deprecated and will be removed after 2018-01-01.
# Instructions for updating:
# Use `tf.profiler.profile(graph, run_meta, op_log, cmd, options)`. Build `options` with `tf.profiler.ProfileOptionBuilder`. See README.md for details
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# W0118 20:27:21.066202 140375671650176 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/profiler/internal/flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 137 ops no flops stats due to incomplete shapes.
# Parsing Inputs...
# Incomplete shape.
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              0
# -min_occurrence             0
# -step                       -1
# -order_by                   name
# -account_type_regexes       _trainable_variables
# -start_name_regexes         .*
# -trim_name_regexes          .*BatchNorm.*
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     params
# -output                     stdout:
#
# ==================Model Analysis Report======================
# Incomplete shape.
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# param: Number of parameters (in the Variable).
#
# Profile:
# node name | # parameters
# _TFProfRoot (--/4.61m params)
#   BoxPredictor_0 (--/13.85k params)
#     BoxPredictor_0/BoxEncodingPredictor (--/6.92k params)
#       BoxPredictor_0/BoxEncodingPredictor/biases (12, 12/12 params)
#       BoxPredictor_0/BoxEncodingPredictor/weights (1x1x576x12, 6.91k/6.91k params)
#     BoxPredictor_0/ClassPredictor (--/6.92k params)
#       BoxPredictor_0/ClassPredictor/biases (12, 12/12 params)
#       BoxPredictor_0/ClassPredictor/weights (1x1x576x12, 6.91k/6.91k params)
#   BoxPredictor_1 (--/61.49k params)
#     BoxPredictor_1/BoxEncodingPredictor (--/30.74k params)
#       BoxPredictor_1/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_1/BoxEncodingPredictor/weights (1x1x1280x24, 30.72k/30.72k params)
#     BoxPredictor_1/ClassPredictor (--/30.74k params)
#       BoxPredictor_1/ClassPredictor/biases (24, 24/24 params)
#       BoxPredictor_1/ClassPredictor/weights (1x1x1280x24, 30.72k/30.72k params)
#   BoxPredictor_2 (--/24.62k params)
#     BoxPredictor_2/BoxEncodingPredictor (--/12.31k params)
#       BoxPredictor_2/BoxEncodingPredictor/biases (24, 24/24 params)
#       BoxPredictor_2/BoxEncodingPredictor/weights (1x1x512x24, 12.29k/12.29k params)
#     BoxPredictor_2/ClassPredictor (--/12.31k params)
#       BoxPredictor_2/ClassPredictor/biases (24, 24/24 params)
#       BoxPredictor_2/ClassPredictor/weights (1x1x512x24, 12.29k/12.29k params)
I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-01-18 20:27:23.062744: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-18 20:27:23.065176: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-18 20:27:23.065219: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-01-18 20:27:23.065237: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-01-18 20:27:23.065371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:23.065953: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:23.066468: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-01-18 20:27:23.066511: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-100000
# I0118 20:27:23.068190 140375671650176 saver.py:1284] Restoring parameters from training/model.ckpt-100000
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# W0118 20:27:24.047705 140375671650176 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/tools/freeze_graph.py:127: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2021-01-18 20:27:24.510156: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:24.510728: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-01-18 20:27:24.510813: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-18 20:27:24.510838: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-01-18 20:27:24.510860: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-01-18 20:27:24.510880: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-01-18 20:27:24.510904: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-01-18 20:27:24.510925: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-01-18 20:27:24.510946: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-01-18 20:27:24.511030: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:24.511569: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:24.512066: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-01-18 20:27:24.512107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-18 20:27:24.512120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-01-18 20:27:24.512136: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-01-18 20:27:24.512239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:24.512802: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:24.513337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-100000
# I0118 20:27:24.514509 140375671650176 saver.py:1284] Restoring parameters from training/model.ckpt-100000
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W0118 20:27:25.573581 140375671650176 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/tools/freeze_graph.py:233: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W0118 20:27:25.573811 140375671650176 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 324 variables.
# I0118 20:27:25.888327 140375671650176 graph_util_impl.py:334] Froze 324 variables.
# INFO:tensorflow:Converted 324 variables to const ops.
# I0118 20:27:25.951525 140375671650176 graph_util_impl.py:394] Converted 324 variables to const ops.
# 2021-01-18 20:27:26.063073: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:26.063663: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-01-18 20:27:26.063746: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-18 20:27:26.063770: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-01-18 20:27:26.063793: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-01-18 20:27:26.063813: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-01-18 20:27:26.063834: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-01-18 20:27:26.063852: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-01-18 20:27:26.063872: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-01-18 20:27:26.063969: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:26.064589: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:26.065091: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-01-18 20:27:26.065141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-18 20:27:26.065157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-01-18 20:27:26.065167: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-01-18 20:27:26.065269: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:26.065787: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 20:27:26.066303: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:384: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0118 20:27:26.529800 140375671650176 deprecation.py:323] From /content/models/research/object_detection/exporter.py:384: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:No assets to save.
# I0118 20:27:26.530448 140375671650176 builder_impl.py:640] No assets to save.
# INFO:tensorflow:No assets to write.
# I0118 20:27:26.530592 140375671650176 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: ./fine_tuned_model/saved_model/saved_model.pb
# I0118 20:27:26.748421 140375671650176 builder_impl.py:425] SavedModel written to: ./fine_tuned_model/saved_model/saved_model.pb
# INFO:tensorflow:Writing pipeline config file to ./fine_tuned_model/pipeline.config
# I0118 20:27:26.768002 140375671650176 config_util.py:254] Writing pipeline config file to ./fine_tuned_model/pipeline.config

# %%
import os

pb_fname = os.path.join(os.path.abspath(output_directory), "frozen_inference_graph.pb")
assert os.path.isfile(pb_fname), '`{}` not exist'.format(pb_fname)

# %% [markdown]
# ## Test accuracy on test images

# %%
pipeline = pipeline_pb2.TrainEvalPipelineConfig()                                                                                                                                                                                                          
config_path = '/content/models/research/object_detection/samples/configs/' + pipeline_file
with tf.gfile.GFile(config_path, "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline)

pipeline.eval_input_reader[0].tf_record_input_reader.input_path[:] = [test_record_fname]
pipeline.train_config.batch_size = 1  # Smaller batch size on free gpu to avoid OOM Killer

config_text = text_format.MessageToString(pipeline)                                                                                                                                                                                                        
with tf.gfile.Open(config_path, "wb") as f:                                                                                                                                                                                                                       
    f.write(config_text)

# This is out config after modifying.
# !cat $config_path
# Out:
# model {
#   ssd {
#     num_classes: 3
#     image_resizer {
#       fixed_shape_resizer {
#         height: 300
#         width: 300
#       }
#     }
#     feature_extractor {
#       type: "ssd_mobilenet_v2"
#       depth_multiplier: 1.0
#       min_depth: 16
#       conv_hyperparams {
#         regularizer {
#           l2_regularizer {
#             weight: 4e-05
#           }
#         }
#         initializer {
#           truncated_normal_initializer {
#             mean: 0.0
#             stddev: 0.03
#           }
#         }
#         activation: RELU_6
#         batch_norm {
#           decay: 0.9997
#           center: true
#           scale: true
#           epsilon: 0.001
#           train: true
#         }
#       }
#     }
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     box_predictor {
#       convolutional_box_predictor {
#         conv_hyperparams {
#           regularizer {
#             l2_regularizer {
#               weight: 4e-05
#             }
#           }
#           initializer {
#             truncated_normal_initializer {
#               mean: 0.0
#               stddev: 0.03
#             }
#           }
#           activation: RELU_6
#           batch_norm {
#             decay: 0.9997
#             center: true
#             scale: true
#             epsilon: 0.001
#             train: true
#           }
#         }
#         min_depth: 0
#         max_depth: 0
#         num_layers_before_predictor: 0
#         use_dropout: false
#         dropout_keep_probability: 0.8
#         kernel_size: 1
#         box_code_size: 4
#         apply_sigmoid_to_scores: false
#       }
#     }
#     anchor_generator {
#       ssd_anchor_generator {
#         num_layers: 6
#         min_scale: 0.2
#         max_scale: 0.95
#         aspect_ratios: 1.0
#         aspect_ratios: 2.0
#         aspect_ratios: 0.5
#         aspect_ratios: 3.0
#         aspect_ratios: 0.3333
#       }
#     }
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 1e-08
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 100
#       }
#       score_converter: SIGMOID
#     }
#     normalize_loss_by_num_matches: true
#     loss {
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       classification_loss {
#         weighted_sigmoid {
#         }
#       }
#       hard_example_miner {
#         num_hard_examples: 3000
#         iou_threshold: 0.99
#         loss_type: CLASSIFICATION
#         max_negatives_per_positive: 3
#         min_negatives_per_image: 3
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#   }
# }
# train_config {
#   batch_size: 1
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     ssd_random_crop {
#     }
#   }
#   optimizer {
#     rms_prop_optimizer {
#       learning_rate {
#         exponential_decay_learning_rate {
#           initial_learning_rate: 0.004
#           decay_steps: 800720
#           decay_factor: 0.95
#         }
#       }
#       momentum_optimizer_value: 0.9
#       decay: 0.9
#       epsilon: 1.0
#     }
#   }
#   fine_tune_checkpoint: "/content/pretrained_model/model.ckpt"
#   num_steps: 100000
#   fine_tune_checkpoint_type: "detection"
# }
# train_input_reader {
#   label_map_path: "/content/data/label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "/content/data/data_train.tfrecord"
#   }
# }
# eval_config {
#   num_examples: 8000
#   max_evals: 10
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
# }
# eval_input_reader {
#   label_map_path: "/content/data/label_map.pbtxt"
#   shuffle: false
#   num_readers: 1
#   tf_record_input_reader {
#     input_path: "/content/data/data_test.tfrecord"
#   }
# }

# %%
# !python /content/models/research/object_detection/model_main.py \
    --pipeline_config_path={config_path} \
    --checkpoint_dir=/content/fine_tuned_model \
    --alsologtostderr \
    --run_once=True
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0118 22:00:56.904992 140301551093632 model_lib.py:793] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0118 22:00:56.905225 140301551093632 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0118 22:00:56.905325 140301551093632 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: 1
# I0118 22:00:56.905411 140301551093632 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: 1
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0118 22:00:56.905494 140301551093632 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W
I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-01-18 22:01:01.804527: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-18 22:01:01.804555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-01-18 22:01:01.804565: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-01-18 22:01:01.804689: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 22:01:01.805199: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-18 22:01:01.805706: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-01-18 22:01:01.805749: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13125 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from /content/fine_tuned_model/model.ckpt
# I0118 22:01:01.807717 140301551093632 saver.py:1284] Restoring parameters from /content/fine_tuned_model/model.ckpt
# INFO:tensorflow:Running local_init_op.
# I0118 22:01:03.042550 140301551093632 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0118 22:01:03.127840 140301551093632 session_manager.py:502] Done running local_init_op.
# 2021-01-18 22:01:04.545262: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-01-18 22:01:05.563259: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# INFO:tensorflow:Performing evaluation on 1055 images.
# I0118 22:01:41.652183 140299150202624 coco_evaluation.py:293] Performing evaluation on 1055 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0118 22:01:41.659393 140299150202624 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.07s)
# I0118 22:01:41.730811 140299150202624 coco_tools.py:138] DONE (t=0.07s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=7.03s).
# Accumulating evaluation results...
# DONE (t=1.07s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.543
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.189
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.470
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.275
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.603
# INFO:tensorflow:Finished evaluation at 2021-01-18-22:01:50
# I0118 22:01:50.022176 140301551093632 evaluation.py:275] Finished evaluation at 2021-01-18-22:01:50
# INFO:tensorflow:Saving dict for global step 100000: DetectionBoxes_Precision/mAP = 0.2935066, DetectionBoxes_Precision/mAP (large) = 0.47023156, DetectionBoxes_Precision/mAP (medium) = 0.39073876, DetectionBoxes_Precision/mAP (small) = 0.18878159, DetectionBoxes_Precision/mAP@.50IOU = 0.5432177, DetectionBoxes_Precision/mAP@.75IOU = 0.29170102, DetectionBoxes_Recall/AR@1 = 0.12762865, DetectionBoxes_Recall/AR@10 = 0.4283758, DetectionBoxes_Recall/AR@100 = 0.46414658, DetectionBoxes_Recall/AR@100 (large) = 0.60336345, DetectionBoxes_Recall/AR@100 (medium) = 0.52599597, DetectionBoxes_Recall/AR@100 (small) = 0.27478072, Loss/classification_loss = 2.7154958, Loss/localization_loss = 0.5960413, Loss/regularization_loss = 0.2896527, Loss/total_loss = 3.6011899, global_step = 100000, learning_rate = 0.004, loss = 3.6011899
# I0118 22:01:50.022501 140301551093632 estimator.py:2049] Saving dict for global step 100000: DetectionBoxes_Precision/mAP = 0.2935066, DetectionBoxes_Precision/mAP (large) = 0.47023156, DetectionBoxes_Precision/mAP (medium) = 0.39073876, DetectionBoxes_Precision/mAP (small) = 0.18878159, DetectionBoxes_Precision/mAP@.50IOU = 0.5432177, DetectionBoxes_Precision/mAP@.75IOU = 0.29170102, DetectionBoxes_Recall/AR@1 = 0.12762865, DetectionBoxes_Recall/AR@10 = 0.4283758, DetectionBoxes_Recall/AR@100 = 0.46414658, DetectionBoxes_Recall/AR@100 (large) = 0.60336345, DetectionBoxes_Recall/AR@100 (medium) = 0.52599597, DetectionBoxes_Recall/AR@100 (small) = 0.27478072, Loss/classification_loss = 2.7154958, Loss/localization_loss = 0.5960413, Loss/regularization_loss = 0.2896527, Loss/total_loss = 3.6011899, global_step = 100000, learning_rate = 0.004, loss = 3.6011899
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100000: /content/fine_tuned_model/model.ckpt
# I0118 22:01:50.627018 140301551093632 estimator.py:2109] Saving 'checkpoint_path' summary for global step 100000: /content/fine_tuned_model/model.ckpt

# %% [markdown]
# ## Run inference test
# Test with images in repository `tensorflow-object-detection/test` directory.
#
# **To test with your own images, you need to place your images inside the `test` directory in this Colab notebook!** More on this below.

# %%
# %cd /content/

if dataset == 1:
  drive_id = '11nAnbp2Rnb9y1p_FjrkKBE4FWDAKtqh5'  # Hardhat
else:
  drive_id = '15XRe167DzTYb7S6fNDAVCrnIr05GJ6jf'  # Scratch

gdd.download_file_from_google_drive(file_id=drive_id,
                                    dest_path='./dataset.zip',
                                    unzip=True)
# !rm dataset.zip
# Out:
# /content
# Downloading 15XRe167DzTYb7S6fNDAVCrnIr05GJ6jf into ./dataset.zip... Done.
# Unzipping...Done.

# %%
import os
import glob

# Path to frozen detection graph. This is the actual model that is used for the object detection.
# PATH_TO_CKPT = pb_fname

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = label_map_pbtxt_fname

# If you want to test the code with your images, just add images files to the PATH_TO_TEST_IMAGES_DIR.
if dataset == 1:
  PATH_TO_TEST_IMAGES_DIR =  '/content/hardhat_test_images/'
else:
  PATH_TO_TEST_IMAGES_DIR =  '/content/scratch_test_images/'

# assert os.path.isfile(pb_fname)
assert os.path.isfile(PATH_TO_LABELS)
TEST_IMAGE_PATHS = glob.glob(os.path.join(PATH_TO_TEST_IMAGES_DIR, "*.jpg*"))
assert len(TEST_IMAGE_PATHS) > 0, 'No image found in `{}`.'.format(PATH_TO_TEST_IMAGES_DIR)
TEST_IMAGE_PATHS = sorted(TEST_IMAGE_PATHS)
if data != 1:
  TEST_IMAGE_PATHS = TEST_IMAGE_PATHS[0:15] + TEST_IMAGE_PATHS[45:60] + TEST_IMAGE_PATHS[90:105] + TEST_IMAGE_PATHS[135:150] + TEST_IMAGE_PATHS[180:195] + TEST_IMAGE_PATHS[225:240]
print(len(TEST_IMAGE_PATHS))
print(TEST_IMAGE_PATHS)
# Out:
# 90
# ['/content/scratch_test_images/crazing_105.jpg', '/content/scratch_test_images/crazing_108.jpg', '/content/scratch_test_images/crazing_135.jpg', '/content/scratch_test_images/crazing_143.jpg', '/content/scratch_test_images/crazing_154.jpg', '/content/scratch_test_images/crazing_155.jpg', '/content/scratch_test_images/crazing_157.jpg', '/content/scratch_test_images/crazing_175.jpg', '/content/scratch_test_images/crazing_176.jpg', '/content/scratch_test_images/crazing_18.jpg', '/content/scratch_test_images/crazing_188.jpg', '/content/scratch_test_images/crazing_189.jpg', '/content/scratch_test_images/crazing_19.jpg', '/content/scratch_test_images/crazing_196.jpg', '/content/scratch_test_images/crazing_198.jpg', '/content/scratch_test_images/inclusion_10.jpg', '/content/scratch_test_images/inclusion_106.jpg', '/content/scratch_test_images/inclusion_136.jpg', '/content/scratch_test_images/inclusion_144.jpg', '/content/scratch_test_images/inclusion_147.jpg', '/content/scratch_test_images/inclusion_149.jpg', '/content/scratch_test_images/inclusion_17.jpg', '/content/scratch_test_images/inclusion_179.jpg', '/content/scratch_test_images/inclusion_184.jpg', '/content/scratch_test_images/inclusion_198.jpg', '/content/scratch_test_images/inclusion_202.jpg', '/content/scratch_test_images/inclusion_208.jpg', '/content/scratch_test_images/inclusion_214.jpg', '/content/scratch_test_images/inclusion_216.jpg', '/content/scratch_test_images/inclusion_221.jpg', '/content/scratch_test_images/patches_10.jpg', '/content/scratch_test_images/patches_103.jpg', '/content/scratch_test_images/patches_104.jpg', '/content/scratch_test_images/patches_106.jpg', '/content/scratch_test_images/patches_111.jpg', '/content/scratch_test_images/patches_124.jpg', '/content/scratch_test_images/patches_132.jpg', '/content/scratch_test_images/patches_152.jpg', '/content/scratch_test_images/patches_155.jpg', '/content/scratch_test_images/patches_161.jpg', '/content/scratch_test_images/patches_177.jpg', '/content/scratch_test_images/patches_179.jpg', '/content/scratch_test_images/patches_182.jpg', '/content/scratch_test_images/patches_187.jpg', '/content/scratch_test_images/patches_189.jpg', '/content/scratch_test_images/pitted_surface_1.jpg', '/content/scratch_test_images/pitted_surface_100.jpg', '/content/scratch_test_images/pitted_surface_108.jpg', '/content/scratch_test_images/pitted_surface_114.jpg', '/content/scratch_test_images/pitted_surface_118.jpg', '/content/scratch_test_images/pitted_surface_12.jpg', '/content/scratch_test_images/pitted_surface_122.jpg', '/content/scratch_test_images/pitted_surface_126.jpg', '/content/scratch_test_images/pitted_surface_134.jpg', '/content/scratch_test_images/pitted_surface_144.jpg', '/content/scratch_test_images/pitted_surface_149.jpg', '/content/scratch_test_images/pitted_surface_16.jpg', '/content/scratch_test_images/pitted_surface_163.jpg', '/content/scratch_test_images/pitted_surface_182.jpg', '/content/scratch_test_images/pitted_surface_188.jpg', '/content/scratch_test_images/rolled-in_scale_1.jpg', '/content/scratch_test_images/rolled-in_scale_113.jpg', '/content/scratch_test_images/rolled-in_scale_124.jpg', '/content/scratch_test_images/rolled-in_scale_130.jpg', '/content/scratch_test_images/rolled-in_scale_131.jpg', '/content/scratch_test_images/rolled-in_scale_135.jpg', '/content/scratch_test_images/rolled-in_scale_142.jpg', '/content/scratch_test_images/rolled-in_scale_149.jpg', '/content/scratch_test_images/rolled-in_scale_152.jpg', '/content/scratch_test_images/rolled-in_scale_155.jpg', '/content/scratch_test_images/rolled-in_scale_156.jpg', '/content/scratch_test_images/rolled-in_scale_158.jpg', '/content/scratch_test_images/rolled-in_scale_166.jpg', '/content/scratch_test_images/rolled-in_scale_169.jpg', '/content/scratch_test_images/rolled-in_scale_17.jpg', '/content/scratch_test_images/scratches_104.jpg', '/content/scratch_test_images/scratches_110.jpg', '/content/scratch_test_images/scratches_125.jpg', '/cont ...

# %%
# %cd /content/models/research/object_detection

import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops


# This is needed to display the images.
# %matplotlib inline


from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util
# Out:
# /content/models/research/object_detection

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')


label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(
    label_map, max_num_classes=num_classes, use_display_name=True)
category_index = label_map_util.create_category_index(categories)


def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
        (im_height, im_width, 3)).astype(np.uint8)

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)


def run_inference_for_single_image(image, graph):
    with graph.as_default():
        with tf.Session() as sess:
            # Get handles to input and output tensors
            ops = tf.get_default_graph().get_operations()
            all_tensor_names = {
                output.name for op in ops for output in op.outputs}
            tensor_dict = {}
            for key in [
                'num_detections', 'detection_boxes', 'detection_scores',
                'detection_classes', 'detection_masks'
            ]:
                tensor_name = key + ':0'
                if tensor_name in all_tensor_names:
                    tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
                        tensor_name)
            if 'detection_masks' in tensor_dict:
                # The following processing is only for single image
                detection_boxes = tf.squeeze(
                    tensor_dict['detection_boxes'], [0])
                detection_masks = tf.squeeze(
                    tensor_dict['detection_masks'], [0])
                # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
                real_num_detection = tf.cast(
                    tensor_dict['num_detections'][0], tf.int32)
                detection_boxes = tf.slice(detection_boxes, [0, 0], [
                                           real_num_detection, -1])
                detection_masks = tf.slice(detection_masks, [0, 0, 0], [
                                           real_num_detection, -1, -1])
                detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                    detection_masks, detection_boxes, image.shape[0], image.shape[1])
                detection_masks_reframed = tf.cast(
                    tf.greater(detection_masks_reframed, 0.5), tf.uint8)
                # Follow the convention by adding back the batch dimension
                tensor_dict['detection_masks'] = tf.expand_dims(
                    detection_masks_reframed, 0)
            image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

            # Run inference
            output_dict = sess.run(tensor_dict,
                                   feed_dict={image_tensor: np.expand_dims(image, 0)})

            # all outputs are float32 numpy arrays, so convert types as appropriate
            output_dict['num_detections'] = int(
                output_dict['num_detections'][0])
            output_dict['detection_classes'] = output_dict[
                'detection_classes'][0].astype(np.uint8)
            output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
            output_dict['detection_scores'] = output_dict['detection_scores'][0]
            if 'detection_masks' in output_dict:
                output_dict['detection_masks'] = output_dict['detection_masks'][0]
    return output_dict

# %%
# Output images not showing? Run this cell again, and try the cell above
# This is needed to display the images.
# %matplotlib inline

# %%
len(TEST_IMAGE_PATHS)
# Out:
# 270

# %%
from tqdm import tqdm

for image_path in tqdm(TEST_IMAGE_PATHS[:100]):
    image = Image.open(image_path)
    # the array based representation of the image will be used later in order to prepare the
    # result image with boxes and labels on it.
    image_np = load_image_into_numpy_array(image)
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    # Actual detection.
    output_dict = run_inference_for_single_image(image_np, detection_graph)
    # Visualization of the results of a detection.
    vis_util.visualize_boxes_and_labels_on_image_array(
        image_np,
        output_dict['detection_boxes'],
        output_dict['detection_classes'],
        output_dict['detection_scores'],
        category_index,
        instance_masks=output_dict.get('detection_masks'),
        use_normalized_coordinates=True,
        line_thickness=4)
    plt.figure(figsize=IMAGE_SIZE)
    plt.imshow(image_np)
    save_name = '.'.join(image_path.split('.')[:-1]) + '_prediction.jpg'
    plt.savefig(save_name, bbox_inches='tight')

# %%
# Download files

from google.colab import files

# !zip -r /content/mobilenet.zip /content/fine_tuned_model/
files.download("/content/mobilenet.zip")

# %%
#take a look at the kind of GPU we have
# !nvidia-smi
# Out:
# Mon Jan 18 21:16:27 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    31W / 250W |   2211MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Download inferred images

# !mkdir /content/result_images
# !cp /content/hardhat_test_images/*_prediction.jpg /content/result_images/

# !zip -r /content/mobilenet_img_results.zip /content/result_images
files.download("/content/mobilenet_img_results.zip")
