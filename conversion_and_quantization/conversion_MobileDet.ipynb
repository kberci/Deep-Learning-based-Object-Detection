# %% [markdown]
# # MobileDet

# %%
model_name = 'ssdlite_mobiledet_cpu_320x320_coco_2020_05_19'
short_name = 'mobiledet'

#Download tensorflow's models folder
# %cd /content/
# !git clone --quiet https://github.com/tensorflow/models.git

# Download and extract checkpoint folder
checkpoint_link = 'http://download.tensorflow.org/models/object_detection/' + model_name + '.tar.gz'
# !rm -rf model_name
# !wget -q $checkpoint_link -O checkpoints.tar.gz
# !tar -xvf checkpoints.tar.gz
# !rm checkpoints.tar.gz

# Rename file
# !mv  $model_name/model.tflite "$model_name"/"$short_name".tflite

#Download file
from google.colab import files
file_path = model_name + '/' + short_name + '.tflite'
files.download(file_path)
# Out:
# /content
